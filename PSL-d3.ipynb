# %%
K.<w> = QuadraticField(-3, embedding=CC(I)*sqrt(CC(3)))
OK = K.ring_of_integers()
U = K.unit_group()

print(OK)
# Out:
# Eisenstein Integers generated by 1/2*w + 1/2 in Number Field in w with defining polynomial x^2 + 3 with w = 1.732050807568878?*I

# %%
def closest_integer(gamma):
    K = gamma.parent()
    OK = K.ring_of_integers()
    
    # 1. Get a basis for the ring of integers
    # This basis is {1, omega}
    basis = OK.basis()
    
    # 2. Embed the lattice and target into R^2
    def embed(element):
        c = CC(element) 
        return vector(RR, [c.real(), c.imag()])

    
    # B is the basis matrix
    B = matrix(RR, [embed(b) for b in basis]).transpose()
    target = embed(gamma)
    
    # Get exact coordinates in the lattice basis
    coords = B.solve_right(target)
    
    # 3. Test all 4 combinations of floor and ceiling for the 2 coordinates
    best_dist = infinity
    best_integer = None
    
    import itertools
    # Defines Nearest Neighbours with integer coefficients (note simple rounding would not work for oblique lattices)
    options = [[floor(c)-1, floor(c), floor(c)+1, ceil(c), ceil(c)+1] for c in coords]
    for p, q in itertools.product(*options):
        candidate = OK([p, q])
        # Calculate Euclidean distance squared in the embedding space
        diff = embed(candidate) - target
        dist_sq = diff.dot_product(diff)
        
        if dist_sq < best_dist:
            best_dist = dist_sq
            best_integer = candidate
            
    return best_integer

# %%
S = [0, 1, -1, 1/2*w + 1/2, -1/2*w -1/2, (1/2*w + 1/2).galois_conjugate(), (-1/2*w - 1/2).galois_conjugate()]
T = [1, -1, 1/2*w + 1/2, -1/2*w -1/2, (1/2*w + 1/2).galois_conjugate(), (-1/2*w - 1/2).galois_conjugate()]

# %%
mats = []
matsupdate = []
for a in S:
    for b in S:
        for c in T:
           for d in S:
               M = matrix(K, [[a, b], [c, d]])
               if M.det() == 1:
                    theta = closest_integer(K(K(-d).quo_rem(K(c))[0])) # closest integer of quotient
                    alpha = K(theta)*K(a) + K(b) # update entry a
                    gamma = K(theta)*K(c) + K(d) # update entry c
                    N = matrix(K, [[alpha, -a], [gamma, -c]])
                    mats.append(M)                 
                    matsupdate.append(N)

# Number and sample
# len(mats), mats

# %%
def max_abs_squared_norm(M):
    """
    Return max of the norms of the elements in the 2x2 matrix M. Works because we are in a quadratic field
    """
    return max((x*x.galois_conjugate() for x in M.list()))

normmats = []
for m in mats:
    normmats.append(max_abs_squared_norm(m))
    
normmatsupdate = []
for m in matsupdate:
    normmatsupdate.append(max_abs_squared_norm(m))

# %%
result = list(zip(mats, matsupdate, normmats, normmatsupdate))
 
for i, (M, N, x, y) in enumerate(result, 1):
    print(f"#{i:3d} matrix {list(map(list, M.rows()))} update {list(map(list, N.rows()))} | norms=({x}, {y})")
# Out:
# #  1 matrix [[0, 1], [-1, 0]] update [[1, 0], [0, 1]] | norms=(1, 1)
# #  2 matrix [[0, 1], [-1, 1]] update [[1, 0], [0, 1]] | norms=(1, 1)
# #  3 matrix [[0, 1], [-1, -1]] update [[1, 0], [0, 1]] | norms=(1, 1)
# #  4 matrix [[0, 1], [-1, 1/2*w + 1/2]] update [[1, 0], [0, 1]] | norms=(1, 1)
# #  5 matrix [[0, 1], [-1, -1/2*w - 1/2]] update [[1, 0], [0, 1]] | norms=(1, 1)
# #  6 matrix [[0, 1], [-1, -1/2*w + 1/2]] update [[1, 0], [0, 1]] | norms=(1, 1)
# #  7 matrix [[0, 1], [-1, 1/2*w - 1/2]] update [[1, 0], [0, 1]] | norms=(1, 1)
# #  8 matrix [[0, -1], [1, 0]] update [[-1, 0], [0, -1]] | norms=(1, 1)
# #  9 matrix [[0, -1], [1, 1]] update [[-1, 0], [0, -1]] | norms=(1, 1)
# # 10 matrix [[0, -1], [1, -1]] update [[-1, 0], [0, -1]] | norms=(1, 1)
# # 11 matrix [[0, -1], [1, 1/2*w + 1/2]] update [[-1, 0], [0, -1]] | norms=(1, 1)
# # 12 matrix [[0, -1], [1, -1/2*w - 1/2]] update [[-1, 0], [0, -1]] | norms=(1, 1)
# # 13 matrix [[0, -1], [1, -1/2*w + 1/2]] update [[-1, 0], [0, -1]] | norms=(1, 1)
# # 14 matrix [[0, -1], [1, 1/2*w - 1/2]] update [[-1, 0], [0, -1]] | norms=(1, 1)
# # 15 matrix [[0, 1/2*w + 1/2], [1/2*w - 1/2, 0]] update [[1/2*w + 1/2, 0], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 16 matrix [[0, 1/2*w + 1/2], [1/2*w - 1/2, 1]] update [[1/2*w + 1/2, 0], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 17 matrix [[0, 1/2*w + 1/2], [1/2*w - 1/2, -1]] update [[1/2*w + 1/2, 0], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 18 matrix [[0, 1/2*w + 1/2], [1/2*w - 1/2, 1/2*w + 1/2]] update [[1/2*w + 1/2, 0], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 19 matrix [[0, 1/2*w + 1/2], [1/2*w - 1/2, -1/2*w - 1/2]] update [[1/2*w + 1/2, 0], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 20 matrix [[0, 1/2*w + 1/2], [1/2*w - 1/2, -1/2*w + 1/2]] update [[1/2*w + 1/2, 0], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 21 matrix [[0, 1/2*w + 1/2], [1/2*w - 1/2, 1/2*w - 1/2]] update [[1/2*w + 1/2, 0], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 22 matrix [[0, -1/2*w - 1/2], [-1/2*w + 1/2, 0]] update [[-1/2*w - 1/2, 0], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 23 matrix [[0, -1/2*w - 1/2], [-1/2*w + 1/2, 1]] update [[-1/2*w - 1/2, 0], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 24 matrix [[0, -1/2*w - 1/2], [-1/2*w + 1/2, -1]] update [[-1/2*w - 1/2, 0], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 25 matrix [[0, -1/2*w - 1/2], [-1/2*w + 1/2, 1/2*w + 1/2]] update [[-1/2*w - 1/2, 0], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 26 matrix [[0, -1/2*w - 1/2], [-1/2*w + 1/2, -1/2*w - 1/2]] update [[-1/2*w - 1/2, 0], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 27 matrix [[0, -1/2*w - 1/2], [-1/2*w + 1/2, -1/2*w + 1/2]] update [[-1/2*w - 1/2, 0], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 28 matrix [[0, -1/2*w - 1/2], [-1/2*w + 1/2, 1/2*w - 1/2]] update [[-1/2*w - 1/2, 0], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 29 matrix [[0, -1/2*w + 1/2], [-1/2*w - 1/2, 0]] update [[-1/2*w + 1/2, 0], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 30 matrix [[0, -1/2*w + 1/2], [-1/2*w - 1/2, 1]] update [[-1/2*w + 1/2, 0], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 31 matrix [[0, -1/2*w + 1/2], [-1/2*w - 1/2, -1]] update [[-1/2*w + 1/2, 0], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 32 matrix [[0, -1/2*w + 1/2], [-1/2*w - 1/2, 1/2*w + 1/2]] update [[-1/2*w + 1/2, 0], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 33 matrix [[0, -1/2*w + 1/2], [-1/2*w - 1/2, -1/2*w - 1/2]] update [[-1/2*w + 1/2, 0], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 34 matrix [[0, -1/2*w + 1/2], [-1/2*w - 1/2, -1/2*w + 1/2]] update [[-1/2*w + 1/2, 0], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 35 matrix [[0, -1/2*w + 1/2], [-1/2*w - 1/2, 1/2*w - 1/2]] update [[-1/2*w + 1/2, 0], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 36 matrix [[0, 1/2*w - 1/2], [1/2*w + 1/2, 0]] update [[1/2*w - 1/2, 0], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 37 matrix [[0, 1/2*w - 1/2], [1/2*w + 1/2, 1]] update [[1/2*w - 1/2, 0], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 38 matrix [[0, 1/2*w - 1/2], [1/2*w + 1/2, -1]] update [[1/2*w - 1/2, 0], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 39 matrix [[0, 1/2*w - 1/2], [1/2*w + 1/2, 1/2*w + 1/2]] update [[1/2*w - 1/2, 0], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 40 matrix [[0, 1/2*w - 1/2], [1/2*w + 1/2, -1/2*w - 1/2]] update [[1/2*w - 1/2, 0], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 41 matrix [[0, 1/2*w - 1/2], [1/2*w + 1/2, -1/2*w + 1/2]] update [[1/2*w - 1/2, 0], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 42 matrix [[0, 1/2*w - 1/2], [1/2*w + 1/2, 1/2*w - 1/2]] update [[1/2*w - 1/2, 0], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 43 matrix [[1, 0], [1, 1]] update [[-1, -1], [0, -1]] | norms=(1, 1)
# # 44 matrix [[1, 0], [-1, 1]] update [[1, -1], [0, 1]] | norms=(1, 1)
# # 45 matrix [[1, 0], [1/2*w + 1/2, 1]] update [[1/2*w - 1/2, -1], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 46 matrix [[1, 0], [-1/2*w - 1/2, 1]] update [[-1/2*w + 1/2, -1], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 47 matrix [[1, 0], [-1/2*w + 1/2, 1]] update [[-1/2*w - 1/2, -1], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 48 matrix [[1, 0], [1/2*w - 1/2, 1]] update [[1/2*w + 1/2, -1], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 49 matrix [[1, 1], [-1, 0]] update [[1, -1], [0, 1]] | norms=(1, 1)
# # 50 matrix [[1, 1], [-1/2*w - 1/2, -1/2*w + 1/2]] update [[-1/2*w + 1/2, -1], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 51 matrix [[1, 1], [1/2*w - 1/2, 1/2*w + 1/2]] update [[1/2*w + 1/2, -1], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 52 matrix [[1, -1], [1, 0]] update [[-1, -1], [0, -1]] | norms=(1, 1)
# # 53 matrix [[1, -1], [1/2*w + 1/2, -1/2*w + 1/2]] update [[1/2*w - 1/2, -1], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 54 matrix [[1, -1], [-1/2*w + 1/2, 1/2*w + 1/2]] update [[-1/2*w - 1/2, -1], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 55 matrix [[1, 1/2*w + 1/2], [-1, -1/2*w + 1/2]] update [[1, -1], [0, 1]] | norms=(1, 1)
# # 56 matrix [[1, 1/2*w + 1/2], [1/2*w + 1/2, 1/2*w + 1/2]] update [[1/2*w - 1/2, -1], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 57 matrix [[1, 1/2*w + 1/2], [1/2*w - 1/2, 0]] update [[1/2*w + 1/2, -1], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 58 matrix [[1, -1/2*w - 1/2], [1, -1/2*w + 1/2]] update [[-1, -1], [0, -1]] | norms=(1, 1)
# # 59 matrix [[1, -1/2*w - 1/2], [-1/2*w - 1/2, 1/2*w + 1/2]] update [[-1/2*w + 1/2, -1], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 60 matrix [[1, -1/2*w - 1/2], [-1/2*w + 1/2, 0]] update [[-1/2*w - 1/2, -1], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 61 matrix [[1, -1/2*w + 1/2], [-1, 1/2*w + 1/2]] update [[1, -1], [0, 1]] | norms=(1, 1)
# # 62 matrix [[1, -1/2*w + 1/2], [-1/2*w - 1/2, 0]] update [[-1/2*w + 1/2, -1], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 63 matrix [[1, -1/2*w + 1/2], [-1/2*w + 1/2, -1/2*w + 1/2]] update [[-1/2*w - 1/2, -1], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 64 matrix [[1, 1/2*w - 1/2], [1, 1/2*w + 1/2]] update [[-1, -1], [0, -1]] | norms=(1, 1)
# # 65 matrix [[1, 1/2*w - 1/2], [1/2*w + 1/2, 0]] update [[1/2*w - 1/2, -1], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 66 matrix [[1, 1/2*w - 1/2], [1/2*w - 1/2, -1/2*w + 1/2]] update [[1/2*w + 1/2, -1], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 67 matrix [[-1, 0], [1, -1]] update [[-1, 1], [0, -1]] | norms=(1, 1)
# # 68 matrix [[-1, 0], [-1, -1]] update [[1, 1], [0, 1]] | norms=(1, 1)
# # 69 matrix [[-1, 0], [1/2*w + 1/2, -1]] update [[1/2*w - 1/2, 1], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 70 matrix [[-1, 0], [-1/2*w - 1/2, -1]] update [[-1/2*w + 1/2, 1], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 71 matrix [[-1, 0], [-1/2*w + 1/2, -1]] update [[-1/2*w - 1/2, 1], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 72 matrix [[-1, 0], [1/2*w - 1/2, -1]] update [[1/2*w + 1/2, 1], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 73 matrix [[-1, 1], [-1, 0]] update [[1, 1], [0, 1]] | norms=(1, 1)
# # 74 matrix [[-1, 1], [-1/2*w - 1/2, 1/2*w - 1/2]] update [[-1/2*w + 1/2, 1], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 75 matrix [[-1, 1], [1/2*w - 1/2, -1/2*w - 1/2]] update [[1/2*w + 1/2, 1], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 76 matrix [[-1, -1], [1, 0]] update [[-1, 1], [0, -1]] | norms=(1, 1)
# # 77 matrix [[-1, -1], [1/2*w + 1/2, 1/2*w - 1/2]] update [[1/2*w - 1/2, 1], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 78 matrix [[-1, -1], [-1/2*w + 1/2, -1/2*w - 1/2]] update [[-1/2*w - 1/2, 1], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 79 matrix [[-1, 1/2*w + 1/2], [-1, 1/2*w - 1/2]] update [[1, 1], [0, 1]] | norms=(1, 1)
# # 80 matrix [[-1, 1/2*w + 1/2], [1/2*w + 1/2, -1/2*w - 1/2]] update [[1/2*w - 1/2, 1], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 81 matrix [[-1, 1/2*w + 1/2], [1/2*w - 1/2, 0]] update [[1/2*w + 1/2, 1], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 82 matrix [[-1, -1/2*w - 1/2], [1, 1/2*w - 1/2]] update [[-1, 1], [0, -1]] | norms=(1, 1)
# # 83 matrix [[-1, -1/2*w - 1/2], [-1/2*w - 1/2, -1/2*w - 1/2]] update [[-1/2*w + 1/2, 1], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 84 matrix [[-1, -1/2*w - 1/2], [-1/2*w + 1/2, 0]] update [[-1/2*w - 1/2, 1], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 85 matrix [[-1, -1/2*w + 1/2], [-1, -1/2*w - 1/2]] update [[1, 1], [0, 1]] | norms=(1, 1)
# # 86 matrix [[-1, -1/2*w + 1/2], [-1/2*w - 1/2, 0]] update [[-1/2*w + 1/2, 1], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 87 matrix [[-1, -1/2*w + 1/2], [-1/2*w + 1/2, 1/2*w - 1/2]] update [[-1/2*w - 1/2, 1], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 88 matrix [[-1, 1/2*w - 1/2], [1, -1/2*w - 1/2]] update [[-1, 1], [0, -1]] | norms=(1, 1)
# # 89 matrix [[-1, 1/2*w - 1/2], [1/2*w + 1/2, 0]] update [[1/2*w - 1/2, 1], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 90 matrix [[-1, 1/2*w - 1/2], [1/2*w - 1/2, 1/2*w - 1/2]] update [[1/2*w + 1/2, 1], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 91 matrix [[1/2*w + 1/2, 0], [1, -1/2*w + 1/2]] update [[-1, -1/2*w - 1/2], [0, -1]] | norms=(1, 1)
# # 92 matrix [[1/2*w + 1/2, 0], [-1, -1/2*w + 1/2]] update [[1, -1/2*w - 1/2], [0, 1]] | norms=(1, 1)
# # 93 matrix [[1/2*w + 1/2, 0], [1/2*w + 1/2, -1/2*w + 1/2]] update [[1/2*w - 1/2, -1/2*w - 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# # 94 matrix [[1/2*w + 1/2, 0], [-1/2*w - 1/2, -1/2*w + 1/2]] update [[-1/2*w + 1/2, -1/2*w - 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 95 matrix [[1/2*w + 1/2, 0], [-1/2*w + 1/2, -1/2*w + 1/2]] update [[-1/2*w - 1/2, -1/2*w - 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# # 96 matrix [[1/2*w + 1/2, 0], [1/2*w - 1/2, -1/2*w + 1/2]] update [[1/2*w + 1/2, -1/2*w - 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# # 97 matrix [[1/2*w + 1/2, 1], [-1, 0]] update [[1, -1/2*w - 1/2], [0, 1]] | norms=(1, 1)
# # 98 matrix [[1/2*w + 1/2, 1], [-1/2*w - 1/2, -1/2*w - 1/2]] update [[-1/2*w + 1/2, -1/2*w - 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# # 99 matrix [[1/2*w + 1/2, 1], [1/2*w - 1/2, 1]] update [[1/2*w + 1/2, -1/2*w - 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #100 matrix [[1/2*w + 1/2, -1], [1, 0]] update [[-1, -1/2*w - 1/2], [0, -1]] | norms=(1, 1)
# #101 matrix [[1/2*w + 1/2, -1], [1/2*w + 1/2, -1/2*w - 1/2]] update [[1/2*w - 1/2, -1/2*w - 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #102 matrix [[1/2*w + 1/2, -1], [-1/2*w + 1/2, 1]] update [[-1/2*w - 1/2, -1/2*w - 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #103 matrix [[1/2*w + 1/2, 1/2*w + 1/2], [-1, -1/2*w - 1/2]] update [[1, -1/2*w - 1/2], [0, 1]] | norms=(1, 1)
# #104 matrix [[1/2*w + 1/2, 1/2*w + 1/2], [1/2*w + 1/2, 1]] update [[1/2*w - 1/2, -1/2*w - 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #105 matrix [[1/2*w + 1/2, 1/2*w + 1/2], [1/2*w - 1/2, 0]] update [[1/2*w + 1/2, -1/2*w - 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #106 matrix [[1/2*w + 1/2, -1/2*w - 1/2], [1, -1/2*w - 1/2]] update [[-1, -1/2*w - 1/2], [0, -1]] | norms=(1, 1)
# #107 matrix [[1/2*w + 1/2, -1/2*w - 1/2], [-1/2*w - 1/2, 1]] update [[-1/2*w + 1/2, -1/2*w - 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #108 matrix [[1/2*w + 1/2, -1/2*w - 1/2], [-1/2*w + 1/2, 0]] update [[-1/2*w - 1/2, -1/2*w - 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #109 matrix [[1/2*w + 1/2, -1/2*w + 1/2], [-1, 1]] update [[1, -1/2*w - 1/2], [0, 1]] | norms=(1, 1)
# #110 matrix [[1/2*w + 1/2, -1/2*w + 1/2], [-1/2*w - 1/2, 0]] update [[-1/2*w + 1/2, -1/2*w - 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #111 matrix [[1/2*w + 1/2, -1/2*w + 1/2], [-1/2*w + 1/2, -1/2*w - 1/2]] update [[-1/2*w - 1/2, -1/2*w - 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #112 matrix [[1/2*w + 1/2, 1/2*w - 1/2], [1, 1]] update [[-1, -1/2*w - 1/2], [0, -1]] | norms=(1, 1)
# #113 matrix [[1/2*w + 1/2, 1/2*w - 1/2], [1/2*w + 1/2, 0]] update [[1/2*w - 1/2, -1/2*w - 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #114 matrix [[1/2*w + 1/2, 1/2*w - 1/2], [1/2*w - 1/2, -1/2*w - 1/2]] update [[1/2*w + 1/2, -1/2*w - 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #115 matrix [[-1/2*w - 1/2, 0], [1, 1/2*w - 1/2]] update [[-1, 1/2*w + 1/2], [0, -1]] | norms=(1, 1)
# #116 matrix [[-1/2*w - 1/2, 0], [-1, 1/2*w - 1/2]] update [[1, 1/2*w + 1/2], [0, 1]] | norms=(1, 1)
# #117 matrix [[-1/2*w - 1/2, 0], [1/2*w + 1/2, 1/2*w - 1/2]] update [[1/2*w - 1/2, 1/2*w + 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #118 matrix [[-1/2*w - 1/2, 0], [-1/2*w - 1/2, 1/2*w - 1/2]] update [[-1/2*w + 1/2, 1/2*w + 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #119 matrix [[-1/2*w - 1/2, 0], [-1/2*w + 1/2, 1/2*w - 1/2]] update [[-1/2*w - 1/2, 1/2*w + 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #120 matrix [[-1/2*w - 1/2, 0], [1/2*w - 1/2, 1/2*w - 1/2]] update [[1/2*w + 1/2, 1/2*w + 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #121 matrix [[-1/2*w - 1/2, 1], [-1, 0]] update [[1, 1/2*w + 1/2], [0, 1]] | norms=(1, 1)
# #122 matrix [[-1/2*w - 1/2, 1], [-1/2*w - 1/2, 1/2*w + 1/2]] update [[-1/2*w + 1/2, 1/2*w + 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #123 matrix [[-1/2*w - 1/2, 1], [1/2*w - 1/2, -1]] update [[1/2*w + 1/2, 1/2*w + 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #124 matrix [[-1/2*w - 1/2, -1], [1, 0]] update [[-1, 1/2*w + 1/2], [0, -1]] | norms=(1, 1)
# #125 matrix [[-1/2*w - 1/2, -1], [1/2*w + 1/2, 1/2*w + 1/2]] update [[1/2*w - 1/2, 1/2*w + 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #126 matrix [[-1/2*w - 1/2, -1], [-1/2*w + 1/2, -1]] update [[-1/2*w - 1/2, 1/2*w + 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #127 matrix [[-1/2*w - 1/2, 1/2*w + 1/2], [-1, 1/2*w + 1/2]] update [[1, 1/2*w + 1/2], [0, 1]] | norms=(1, 1)
# #128 matrix [[-1/2*w - 1/2, 1/2*w + 1/2], [1/2*w + 1/2, -1]] update [[1/2*w - 1/2, 1/2*w + 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #129 matrix [[-1/2*w - 1/2, 1/2*w + 1/2], [1/2*w - 1/2, 0]] update [[1/2*w + 1/2, 1/2*w + 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #130 matrix [[-1/2*w - 1/2, -1/2*w - 1/2], [1, 1/2*w + 1/2]] update [[-1, 1/2*w + 1/2], [0, -1]] | norms=(1, 1)
# #131 matrix [[-1/2*w - 1/2, -1/2*w - 1/2], [-1/2*w - 1/2, -1]] update [[-1/2*w + 1/2, 1/2*w + 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #132 matrix [[-1/2*w - 1/2, -1/2*w - 1/2], [-1/2*w + 1/2, 0]] update [[-1/2*w - 1/2, 1/2*w + 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #133 matrix [[-1/2*w - 1/2, -1/2*w + 1/2], [-1, -1]] update [[1, 1/2*w + 1/2], [0, 1]] | norms=(1, 1)
# #134 matrix [[-1/2*w - 1/2, -1/2*w + 1/2], [-1/2*w - 1/2, 0]] update [[-1/2*w + 1/2, 1/2*w + 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #135 matrix [[-1/2*w - 1/2, -1/2*w + 1/2], [-1/2*w + 1/2, 1/2*w + 1/2]] update [[-1/2*w - 1/2, 1/2*w + 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #136 matrix [[-1/2*w - 1/2, 1/2*w - 1/2], [1, -1]] update [[-1, 1/2*w + 1/2], [0, -1]] | norms=(1, 1)
# #137 matrix [[-1/2*w - 1/2, 1/2*w - 1/2], [1/2*w + 1/2, 0]] update [[1/2*w - 1/2, 1/2*w + 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #138 matrix [[-1/2*w - 1/2, 1/2*w - 1/2], [1/2*w - 1/2, 1/2*w + 1/2]] update [[1/2*w + 1/2, 1/2*w + 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #139 matrix [[-1/2*w + 1/2, 0], [1, 1/2*w + 1/2]] update [[-1, 1/2*w - 1/2], [0, -1]] | norms=(1, 1)
# #140 matrix [[-1/2*w + 1/2, 0], [-1, 1/2*w + 1/2]] update [[1, 1/2*w - 1/2], [0, 1]] | norms=(1, 1)
# #141 matrix [[-1/2*w + 1/2, 0], [1/2*w + 1/2, 1/2*w + 1/2]] update [[1/2*w - 1/2, 1/2*w - 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #142 matrix [[-1/2*w + 1/2, 0], [-1/2*w - 1/2, 1/2*w + 1/2]] update [[-1/2*w + 1/2, 1/2*w - 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #143 matrix [[-1/2*w + 1/2, 0], [-1/2*w + 1/2, 1/2*w + 1/2]] update [[-1/2*w - 1/2, 1/2*w - 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #144 matrix [[-1/2*w + 1/2, 0], [1/2*w - 1/2, 1/2*w + 1/2]] update [[1/2*w + 1/2, 1/2*w - 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #145 matrix [[-1/2*w + 1/2, 1], [-1, 0]] update [[1, 1/2*w - 1/2], [0, 1]] | norms=(1, 1)
# #146 matrix [[-1/2*w + 1/2, 1], [-1/2*w - 1/2, 1]] update [[-1/2*w + 1/2, 1/2*w - 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #147 matrix [[-1/2*w + 1/2, 1], [1/2*w - 1/2, 1/2*w - 1/2]] update [[1/2*w + 1/2, 1/2*w - 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #148 matrix [[-1/2*w + 1/2, -1], [1, 0]] update [[-1, 1/2*w - 1/2], [0, -1]] | norms=(1, 1)
# #149 matrix [[-1/2*w + 1/2, -1], [1/2*w + 1/2, 1]] update [[1/2*w - 1/2, 1/2*w - 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #150 matrix [[-1/2*w + 1/2, -1], [-1/2*w + 1/2, 1/2*w - 1/2]] update [[-1/2*w - 1/2, 1/2*w - 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #151 matrix [[-1/2*w + 1/2, 1/2*w + 1/2], [-1, 1]] update [[1, 1/2*w - 1/2], [0, 1]] | norms=(1, 1)
# #152 matrix [[-1/2*w + 1/2, 1/2*w + 1/2], [1/2*w + 1/2, 1/2*w - 1/2]] update [[1/2*w - 1/2, 1/2*w - 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #153 matrix [[-1/2*w + 1/2, 1/2*w + 1/2], [1/2*w - 1/2, 0]] update [[1/2*w + 1/2, 1/2*w - 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #154 matrix [[-1/2*w + 1/2, -1/2*w - 1/2], [1, 1]] update [[-1, 1/2*w - 1/2], [0, -1]] | norms=(1, 1)
# #155 matrix [[-1/2*w + 1/2, -1/2*w - 1/2], [-1/2*w - 1/2, 1/2*w - 1/2]] update [[-1/2*w + 1/2, 1/2*w - 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #156 matrix [[-1/2*w + 1/2, -1/2*w - 1/2], [-1/2*w + 1/2, 0]] update [[-1/2*w - 1/2, 1/2*w - 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #157 matrix [[-1/2*w + 1/2, -1/2*w + 1/2], [-1, 1/2*w - 1/2]] update [[1, 1/2*w - 1/2], [0, 1]] | norms=(1, 1)
# #158 matrix [[-1/2*w + 1/2, -1/2*w + 1/2], [-1/2*w - 1/2, 0]] update [[-1/2*w + 1/2, 1/2*w - 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #159 matrix [[-1/2*w + 1/2, -1/2*w + 1/2], [-1/2*w + 1/2, 1]] update [[-1/2*w - 1/2, 1/2*w - 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #160 matrix [[-1/2*w + 1/2, 1/2*w - 1/2], [1, 1/2*w - 1/2]] update [[-1, 1/2*w - 1/2], [0, -1]] | norms=(1, 1)
# #161 matrix [[-1/2*w + 1/2, 1/2*w - 1/2], [1/2*w + 1/2, 0]] update [[1/2*w - 1/2, 1/2*w - 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #162 matrix [[-1/2*w + 1/2, 1/2*w - 1/2], [1/2*w - 1/2, 1]] update [[1/2*w + 1/2, 1/2*w - 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #163 matrix [[1/2*w - 1/2, 0], [1, -1/2*w - 1/2]] update [[-1, -1/2*w + 1/2], [0, -1]] | norms=(1, 1)
# #164 matrix [[1/2*w - 1/2, 0], [-1, -1/2*w - 1/2]] update [[1, -1/2*w + 1/2], [0, 1]] | norms=(1, 1)
# #165 matrix [[1/2*w - 1/2, 0], [1/2*w + 1/2, -1/2*w - 1/2]] update [[1/2*w - 1/2, -1/2*w + 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #166 matrix [[1/2*w - 1/2, 0], [-1/2*w - 1/2, -1/2*w - 1/2]] update [[-1/2*w + 1/2, -1/2*w + 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #167 matrix [[1/2*w - 1/2, 0], [-1/2*w + 1/2, -1/2*w - 1/2]] update [[-1/2*w - 1/2, -1/2*w + 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #168 matrix [[1/2*w - 1/2, 0], [1/2*w - 1/2, -1/2*w - 1/2]] update [[1/2*w + 1/2, -1/2*w + 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #169 matrix [[1/2*w - 1/2, 1], [-1, 0]] update [[1, -1/2*w + 1/2], [0, 1]] | norms=(1, 1)
# #170 matrix [[1/2*w - 1/2, 1], [-1/2*w - 1/2, -1]] update [[-1/2*w + 1/2, -1/2*w + 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #171 matrix [[1/2*w - 1/2, 1], [1/2*w - 1/2, -1/2*w + 1/2]] update [[1/2*w + 1/2, -1/2*w + 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #172 matrix [[1/2*w - 1/2, -1], [1, 0]] update [[-1, -1/2*w + 1/2], [0, -1]] | norms=(1, 1)
# #173 matrix [[1/2*w - 1/2, -1], [1/2*w + 1/2, -1]] update [[1/2*w - 1/2, -1/2*w + 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #174 matrix [[1/2*w - 1/2, -1], [-1/2*w + 1/2, -1/2*w + 1/2]] update [[-1/2*w - 1/2, -1/2*w + 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #175 matrix [[1/2*w - 1/2, 1/2*w + 1/2], [-1, -1]] update [[1, -1/2*w + 1/2], [0, 1]] | norms=(1, 1)
# #176 matrix [[1/2*w - 1/2, 1/2*w + 1/2], [1/2*w + 1/2, -1/2*w + 1/2]] update [[1/2*w - 1/2, -1/2*w + 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #177 matrix [[1/2*w - 1/2, 1/2*w + 1/2], [1/2*w - 1/2, 0]] update [[1/2*w + 1/2, -1/2*w + 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)
# #178 matrix [[1/2*w - 1/2, -1/2*w - 1/2], [1, -1]] update [[-1, -1/2*w + 1/2], [0, -1]] | norms=(1, 1)
# #179 matrix [[1/2*w - 1/2, -1/2*w - 1/2], [-1/2*w - 1/2, -1/2*w + 1/2]] update [[-1/2*w + 1/2, -1/2*w + 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #180 matrix [[1/2*w - 1/2, -1/2*w - 1/2], [-1/2*w + 1/2, 0]] update [[-1/2*w - 1/2, -1/2*w + 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #181 matrix [[1/2*w - 1/2, -1/2*w + 1/2], [-1, -1/2*w + 1/2]] update [[1, -1/2*w + 1/2], [0, 1]] | norms=(1, 1)
# #182 matrix [[1/2*w - 1/2, -1/2*w + 1/2], [-1/2*w - 1/2, 0]] update [[-1/2*w + 1/2, -1/2*w + 1/2], [0, 1/2*w + 1/2]] | norms=(1, 1)
# #183 matrix [[1/2*w - 1/2, -1/2*w + 1/2], [-1/2*w + 1/2, -1]] update [[-1/2*w - 1/2, -1/2*w + 1/2], [0, 1/2*w - 1/2]] | norms=(1, 1)
# #184 matrix [[1/2*w - 1/2, 1/2*w - 1/2], [1, -1/2*w + 1/2]] update [[-1, -1/2*w + 1/2], [0, -1]] | norms=(1, 1)
# #185 matrix [[1/2*w - 1/2, 1/2*w - 1/2], [1/2*w + 1/2, 0]] update [[1/2*w - 1/2, -1/2*w + 1/2], [0, -1/2*w - 1/2]] | norms=(1, 1)
# #186 matrix [[1/2*w - 1/2, 1/2*w - 1/2], [1/2*w - 1/2, -1]] update [[1/2*w + 1/2, -1/2*w + 1/2], [0, -1/2*w + 1/2]] | norms=(1, 1)

# %%
for i, (M, N, x, y) in enumerate(result, 1):
    if x < y:
        print(f"#{i:3d} matrix {list(map(list, M.rows()))} update {list(map(list, N.rows()))} | norms=({x}, {y})")
