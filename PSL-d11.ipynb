# %%
K.<w> = QuadraticField(-11, embedding=CC(I)*sqrt(CC(11)))
OK = K.ring_of_integers()
U = K.unit_group()

print(OK)
# Out:
# Maximal Order generated by 1/2*w + 1/2 in Number Field in w with defining polynomial x^2 + 11 with w = 3.316624790355400?*I

# %%
def closest_integer(gamma):
    K = gamma.parent()
    OK = K.ring_of_integers()
    
    # 1. Get a basis for the ring of integers
    # This basis is {1, omega}
    basis = OK.basis()
    
    # 2. Embed the lattice and target into R^2
    def embed(element):
        c = CC(element) 
        return vector(RR, [c.real(), c.imag()])

    
    # B is the basis matrix
    B = matrix(RR, [embed(b) for b in basis]).transpose()
    target = embed(gamma)
    
    # Get exact coordinates in the lattice basis
    coords = B.solve_right(target)
    
    # 3. Test all 4 combinations of floor and ceiling for the 2 coordinates
    best_dist = infinity
    best_integer = None
    
    import itertools
    # Defines Nearest Neighbours with integer coefficients (note simple rounding would not work for oblique lattices)
    options = [[floor(c)-1, floor(c), floor(c)+1] for c in coords]
    for p, q in itertools.product(*options):
        candidate = OK([p, q])
        # Calculate Euclidean distance squared in the embedding space
        diff = embed(candidate) - target
        dist_sq = diff.dot_product(diff)
        
        if dist_sq < best_dist:
            best_dist = dist_sq
            best_integer = candidate
            
    return best_integer

# %%
units = [1, -1]

# print(f"units of norm 1: {K.elements_of_norm(1)}")

N0 = sorted({u*n for u in units for n in K.elements_of_norm(0)});
N1 = sorted({u*n for u in units for n in K.elements_of_norm(1)});
N2 = sorted({u*n for u in units for n in K.elements_of_norm(2)});
N3 = sorted({u*n for u in units for n in K.elements_of_norm(3)});
N4 = sorted({u*n for u in units for n in K.elements_of_norm(4)});
N5 = sorted({u*n for u in units for n in K.elements_of_norm(5)});

S = N0 + N1 + N2 + N3 + N4 + N5; S
T = N1 + N2 + N3 + N4 + N5;

# %%
mats = []
matsupdate = []
for a in S:
    for b in S:
        for c in T:
           for d in S:
               M = matrix(K, [[a, b], [c, d]])
               if M.det() == 1:
                    theta = closest_integer(K(K(-d).quo_rem(K(c))[0])) # closest integer of quotient
                    alpha = K(theta)*K(a) + K(b) # update entry a
                    gamma = K(theta)*K(c) + K(d) # update entry c
                    N = matrix(K, [[alpha, -a], [gamma, -c]])
                    mats.append(M)                 
                    matsupdate.append(N)

# %%
def max_abs_squared_norm(M):
    """
    Return max of the norms of the elements in the 2x2 matrix M. Works because we are in a quadratic field
    """
    return max((x*x.galois_conjugate() for x in M.list()))

normmats = []
for m in mats:
    normmats.append(max_abs_squared_norm(m))
    
normmatsupdate = []
for m in matsupdate:
    normmatsupdate.append(max_abs_squared_norm(m))

# %%
result = list(zip(mats, matsupdate, normmats, normmatsupdate))
 
for i, (M, N, x, y) in enumerate(result, 1):
    print(f"#{i:3d} matrix {list(map(list, M.rows()))} update {list(map(list, N.rows()))} | norms=({x}, {y})")
# Out:
# #  1 matrix [[0, -1], [1, 0]] update [[-1, 0], [0, -1]] | norms=(1, 1)
# #  2 matrix [[0, -1], [1, -1]] update [[-1, 0], [0, -1]] | norms=(1, 1)
# #  3 matrix [[0, -1], [1, 1]] update [[-1, 0], [0, -1]] | norms=(1, 1)
# #  4 matrix [[0, -1], [1, -1/2*w - 1/2]] update [[-1, 0], [0, -1]] | norms=(3, 1)
# #  5 matrix [[0, -1], [1, 1/2*w - 1/2]] update [[-1, 0], [0, -1]] | norms=(3, 1)
# #  6 matrix [[0, -1], [1, -1/2*w + 1/2]] update [[-1, 0], [0, -1]] | norms=(3, 1)
# #  7 matrix [[0, -1], [1, 1/2*w + 1/2]] update [[-1, 0], [0, -1]] | norms=(3, 1)
# #  8 matrix [[0, -1], [1, -2]] update [[-1, 0], [0, -1]] | norms=(4, 1)
# #  9 matrix [[0, -1], [1, 2]] update [[-1, 0], [0, -1]] | norms=(4, 1)
# # 10 matrix [[0, -1], [1, -1/2*w - 3/2]] update [[-1, 0], [0, -1]] | norms=(5, 1)
# # 11 matrix [[0, -1], [1, 1/2*w - 3/2]] update [[-1, 0], [0, -1]] | norms=(5, 1)
# # 12 matrix [[0, -1], [1, -1/2*w + 3/2]] update [[-1, 0], [0, -1]] | norms=(5, 1)
# # 13 matrix [[0, -1], [1, 1/2*w + 3/2]] update [[-1, 0], [0, -1]] | norms=(5, 1)
# # 14 matrix [[0, 1], [-1, 0]] update [[1, 0], [0, 1]] | norms=(1, 1)
# # 15 matrix [[0, 1], [-1, -1]] update [[1, 0], [0, 1]] | norms=(1, 1)
# # 16 matrix [[0, 1], [-1, 1]] update [[1, 0], [0, 1]] | norms=(1, 1)
# # 17 matrix [[0, 1], [-1, -1/2*w - 1/2]] update [[1, 0], [0, 1]] | norms=(3, 1)
# # 18 matrix [[0, 1], [-1, 1/2*w - 1/2]] update [[1, 0], [0, 1]] | norms=(3, 1)
# # 19 matrix [[0, 1], [-1, -1/2*w + 1/2]] update [[1, 0], [0, 1]] | norms=(3, 1)
# # 20 matrix [[0, 1], [-1, 1/2*w + 1/2]] update [[1, 0], [0, 1]] | norms=(3, 1)
# # 21 matrix [[0, 1], [-1, -2]] update [[1, 0], [0, 1]] | norms=(4, 1)
# # 22 matrix [[0, 1], [-1, 2]] update [[1, 0], [0, 1]] | norms=(4, 1)
# # 23 matrix [[0, 1], [-1, -1/2*w - 3/2]] update [[1, 0], [0, 1]] | norms=(5, 1)
# # 24 matrix [[0, 1], [-1, 1/2*w - 3/2]] update [[1, 0], [0, 1]] | norms=(5, 1)
# # 25 matrix [[0, 1], [-1, -1/2*w + 3/2]] update [[1, 0], [0, 1]] | norms=(5, 1)
# # 26 matrix [[0, 1], [-1, 1/2*w + 3/2]] update [[1, 0], [0, 1]] | norms=(5, 1)
# # 27 matrix [[-1, 0], [-1, -1]] update [[1, 1], [0, 1]] | norms=(1, 1)
# # 28 matrix [[-1, 0], [1, -1]] update [[-1, 1], [0, -1]] | norms=(1, 1)
# # 29 matrix [[-1, 0], [-1/2*w - 1/2, -1]] update [[0, 1], [-1, 1/2*w + 1/2]] | norms=(3, 3)
# # 30 matrix [[-1, 0], [1/2*w - 1/2, -1]] update [[0, 1], [-1, -1/2*w + 1/2]] | norms=(3, 3)
# # 31 matrix [[-1, 0], [-1/2*w + 1/2, -1]] update [[0, 1], [-1, 1/2*w - 1/2]] | norms=(3, 3)
# # 32 matrix [[-1, 0], [1/2*w + 1/2, -1]] update [[0, 1], [-1, -1/2*w - 1/2]] | norms=(3, 3)
# # 33 matrix [[-1, 0], [-2, -1]] update [[1, 1], [1, 2]] | norms=(4, 4)
# # 34 matrix [[-1, 0], [2, -1]] update [[0, 1], [-1, -2]] | norms=(4, 4)
# # 35 matrix [[-1, 0], [-1/2*w - 3/2, -1]] update [[0, 1], [-1, 1/2*w + 3/2]] | norms=(5, 5)
# # 36 matrix [[-1, 0], [1/2*w - 3/2, -1]] update [[0, 1], [-1, -1/2*w + 3/2]] | norms=(5, 5)
# # 37 matrix [[-1, 0], [-1/2*w + 3/2, -1]] update [[0, 1], [-1, 1/2*w - 3/2]] | norms=(5, 5)
# # 38 matrix [[-1, 0], [1/2*w + 3/2, -1]] update [[0, 1], [-1, -1/2*w - 3/2]] | norms=(5, 5)
# # 39 matrix [[-1, -1], [-1, -2]] update [[1, 1], [0, 1]] | norms=(4, 1)
# # 40 matrix [[-1, -1], [1, 0]] update [[-1, 1], [0, -1]] | norms=(1, 1)
# # 41 matrix [[-1, -1], [-1/2*w - 1/2, -1/2*w - 3/2]] update [[0, 1], [-1, 1/2*w + 1/2]] | norms=(5, 3)
# # 42 matrix [[-1, -1], [1/2*w - 1/2, 1/2*w - 3/2]] update [[0, 1], [-1, -1/2*w + 1/2]] | norms=(5, 3)
# # 43 matrix [[-1, -1], [-1/2*w + 1/2, -1/2*w - 1/2]] update [[0, 1], [-1, 1/2*w - 1/2]] | norms=(3, 3)
# # 44 matrix [[-1, -1], [1/2*w + 1/2, 1/2*w - 1/2]] update [[0, 1], [-1, -1/2*w - 1/2]] | norms=(3, 3)
# # 45 matrix [[-1, -1], [2, 1]] update [[0, 1], [-1, -2]] | norms=(4, 4)
# # 46 matrix [[-1, -1], [-1/2*w + 3/2, -1/2*w + 1/2]] update [[0, 1], [-1, 1/2*w - 3/2]] | norms=(5, 5)
# # 47 matrix [[-1, -1], [1/2*w + 3/2, 1/2*w + 1/2]] update [[0, 1], [-1, -1/2*w - 3/2]] | norms=(5, 5)
# # 48 matrix [[-1, 1], [-1, 0]] update [[1, 1], [0, 1]] | norms=(1, 1)
# # 49 matrix [[-1, 1], [1, -2]] update [[-1, 1], [0, -1]] | norms=(4, 1)
# # 50 matrix [[-1, 1], [-1/2*w - 1/2, 1/2*w - 1/2]] update [[0, 1], [-1, 1/2*w + 1/2]] | norms=(3, 3)
# # 51 matrix [[-1, 1], [1/2*w - 1/2, -1/2*w - 1/2]] update [[0, 1], [-1, -1/2*w + 1/2]] | norms=(3, 3)
# # 52 matrix [[-1, 1], [-1/2*w + 1/2, 1/2*w - 3/2]] update [[0, 1], [-1, 1/2*w - 1/2]] | norms=(5, 3)
# # 53 matrix [[-1, 1], [1/2*w + 1/2, -1/2*w - 3/2]] update [[0, 1], [-1, -1/2*w - 1/2]] | norms=(5, 3)
# # 54 matrix [[-1, 1], [-2, 1]] update [[1, 1], [1, 2]] | norms=(4, 4)
# # 55 matrix [[-1, 1], [-1/2*w - 3/2, 1/2*w + 1/2]] update [[0, 1], [-1, 1/2*w + 3/2]] | norms=(5, 5)
# # 56 matrix [[-1, 1], [1/2*w - 3/2, -1/2*w + 1/2]] update [[0, 1], [-1, -1/2*w + 3/2]] | norms=(5, 5)
# # 57 matrix [[-1, -1/2*w - 1/2], [-1, -1/2*w - 3/2]] update [[1, 1], [0, 1]] | norms=(5, 1)
# # 58 matrix [[-1, -1/2*w - 1/2], [1, 1/2*w - 1/2]] update [[-1, 1], [0, -1]] | norms=(3, 1)
# # 59 matrix [[-1, -1/2*w - 1/2], [-1/2*w - 1/2, -1/2*w + 3/2]] update [[0, 1], [-1, 1/2*w + 1/2]] | norms=(5, 3)
# # 60 matrix [[-1, -1/2*w - 1/2], [-1/2*w + 1/2, 2]] update [[0, 1], [-1, 1/2*w - 1/2]] | norms=(4, 3)
# # 61 matrix [[-1, 1/2*w - 1/2], [-1, 1/2*w - 3/2]] update [[1, 1], [0, 1]] | norms=(5, 1)
# # 62 matrix [[-1, 1/2*w - 1/2], [1, -1/2*w - 1/2]] update [[-1, 1], [0, -1]] | norms=(3, 1)
# # 63 matrix [[-1, 1/2*w - 1/2], [1/2*w - 1/2, 1/2*w + 3/2]] update [[0, 1], [-1, -1/2*w + 1/2]] | norms=(5, 3)
# # 64 matrix [[-1, 1/2*w - 1/2], [1/2*w + 1/2, 2]] update [[0, 1], [-1, -1/2*w - 1/2]] | norms=(4, 3)
# # 65 matrix [[-1, -1/2*w + 1/2], [-1, -1/2*w - 1/2]] update [[1, 1], [0, 1]] | norms=(3, 1)
# # 66 matrix [[-1, -1/2*w + 1/2], [1, 1/2*w - 3/2]] update [[-1, 1], [0, -1]] | norms=(5, 1)
# # 67 matrix [[-1, -1/2*w + 1/2], [-1/2*w - 1/2, 2]] update [[0, 1], [-1, 1/2*w + 1/2]] | norms=(4, 3)
# # 68 matrix [[-1, -1/2*w + 1/2], [-1/2*w + 1/2, 1/2*w + 3/2]] update [[0, 1], [-1, 1/2*w - 1/2]] | norms=(5, 3)
# # 69 matrix [[-1, 1/2*w + 1/2], [-1, 1/2*w - 1/2]] update [[1, 1], [0, 1]] | norms=(3, 1)
# # 70 matrix [[-1, 1/2*w + 1/2], [1, -1/2*w - 3/2]] update [[-1, 1], [0, -1]] | norms=(5, 1)
# # 71 matrix [[-1, 1/2*w + 1/2], [1/2*w - 1/2, 2]] update [[0, 1], [-1, -1/2*w + 1/2]] | norms=(4, 3)
# # 72 matrix [[-1, 1/2*w + 1/2], [1/2*w + 1/2, -1/2*w + 3/2]] update [[0, 1], [-1, -1/2*w - 1/2]] | norms=(5, 3)
# # 73 matrix [[-1, -2], [1, 1]] update [[-1, 1], [0, -1]] | norms=(4, 1)
# # 74 matrix [[-1, 2], [-1, 1]] update [[1, 1], [0, 1]] | norms=(4, 1)
# # 75 matrix [[-1, -1/2*w - 3/2], [1, 1/2*w + 1/2]] update [[-1, 1], [0, -1]] | norms=(5, 1)
# # 76 matrix [[-1, 1/2*w - 3/2], [1, -1/2*w + 1/2]] update [[-1, 1], [0, -1]] | norms=(5, 1)
# # 77 matrix [[-1, -1/2*w + 3/2], [-1, -1/2*w + 1/2]] update [[1, 1], [0, 1]] | norms=(5, 1)
# # 78 matrix [[-1, 1/2*w + 3/2], [-1, 1/2*w + 1/2]] update [[1, 1], [0, 1]] | norms=(5, 1)
# # 79 matrix [[1, 0], [-1, 1]] update [[1, -1], [0, 1]] | norms=(1, 1)
# # 80 matrix [[1, 0], [1, 1]] update [[-1, -1], [0, -1]] | norms=(1, 1)
# # 81 matrix [[1, 0], [-1/2*w - 1/2, 1]] update [[0, -1], [1, 1/2*w + 1/2]] | norms=(3, 3)
# # 82 matrix [[1, 0], [1/2*w - 1/2, 1]] update [[0, -1], [1, -1/2*w + 1/2]] | norms=(3, 3)
# # 83 matrix [[1, 0], [-1/2*w + 1/2, 1]] update [[0, -1], [1, 1/2*w - 1/2]] | norms=(3, 3)
# # 84 matrix [[1, 0], [1/2*w + 1/2, 1]] update [[0, -1], [1, -1/2*w - 1/2]] | norms=(3, 3)
# # 85 matrix [[1, 0], [-2, 1]] update [[0, -1], [1, 2]] | norms=(4, 4)
# # 86 matrix [[1, 0], [2, 1]] update [[-1, -1], [-1, -2]] | norms=(4, 4)
# # 87 matrix [[1, 0], [-1/2*w - 3/2, 1]] update [[0, -1], [1, 1/2*w + 3/2]] | norms=(5, 5)
# # 88 matrix [[1, 0], [1/2*w - 3/2, 1]] update [[0, -1], [1, -1/2*w + 3/2]] | norms=(5, 5)
# # 89 matrix [[1, 0], [-1/2*w + 3/2, 1]] update [[0, -1], [1, 1/2*w - 3/2]] | norms=(5, 5)
# # 90 matrix [[1, 0], [1/2*w + 3/2, 1]] update [[0, -1], [1, -1/2*w - 3/2]] | norms=(5, 5)
# # 91 matrix [[1, -1], [-1, 2]] update [[1, -1], [0, 1]] | norms=(4, 1)
# # 92 matrix [[1, -1], [1, 0]] update [[-1, -1], [0, -1]] | norms=(1, 1)
# # 93 matrix [[1, -1], [-1/2*w - 1/2, 1/2*w + 3/2]] update [[0, -1], [1, 1/2*w + 1/2]] | norms=(5, 3)
# # 94 matrix [[1, -1], [1/2*w - 1/2, -1/2*w + 3/2]] update [[0, -1], [1, -1/2*w + 1/2]] | norms=(5, 3)
# # 95 matrix [[1, -1], [-1/2*w + 1/2, 1/2*w + 1/2]] update [[0, -1], [1, 1/2*w - 1/2]] | norms=(3, 3)
# # 96 matrix [[1, -1], [1/2*w + 1/2, -1/2*w + 1/2]] update [[0, -1], [1, -1/2*w - 1/2]] | norms=(3, 3)
# # 97 matrix [[1, -1], [2, -1]] update [[-1, -1], [-1, -2]] | norms=(4, 4)
# # 98 matrix [[1, -1], [-1/2*w + 3/2, 1/2*w - 1/2]] update [[0, -1], [1, 1/2*w - 3/2]] | norms=(5, 5)
# # 99 matrix [[1, -1], [1/2*w + 3/2, -1/2*w - 1/2]] update [[0, -1], [1, -1/2*w - 3/2]] | norms=(5, 5)
# #100 matrix [[1, 1], [-1, 0]] update [[1, -1], [0, 1]] | norms=(1, 1)
# #101 matrix [[1, 1], [1, 2]] update [[-1, -1], [0, -1]] | norms=(4, 1)
# #102 matrix [[1, 1], [-1/2*w - 1/2, -1/2*w + 1/2]] update [[0, -1], [1, 1/2*w + 1/2]] | norms=(3, 3)
# #103 matrix [[1, 1], [1/2*w - 1/2, 1/2*w + 1/2]] update [[0, -1], [1, -1/2*w + 1/2]] | norms=(3, 3)
# #104 matrix [[1, 1], [-1/2*w + 1/2, -1/2*w + 3/2]] update [[0, -1], [1, 1/2*w - 1/2]] | norms=(5, 3)
# #105 matrix [[1, 1], [1/2*w + 1/2, 1/2*w + 3/2]] update [[0, -1], [1, -1/2*w - 1/2]] | norms=(5, 3)
# #106 matrix [[1, 1], [-2, -1]] update [[0, -1], [1, 2]] | norms=(4, 4)
# #107 matrix [[1, 1], [-1/2*w - 3/2, -1/2*w - 1/2]] update [[0, -1], [1, 1/2*w + 3/2]] | norms=(5, 5)
# #108 matrix [[1, 1], [1/2*w - 3/2, 1/2*w - 1/2]] update [[0, -1], [1, -1/2*w + 3/2]] | norms=(5, 5)
# #109 matrix [[1, -1/2*w - 1/2], [-1, 1/2*w + 3/2]] update [[1, -1], [0, 1]] | norms=(5, 1)
# #110 matrix [[1, -1/2*w - 1/2], [1, -1/2*w + 1/2]] update [[-1, -1], [0, -1]] | norms=(3, 1)
# #111 matrix [[1, -1/2*w - 1/2], [-1/2*w - 1/2, 1/2*w - 3/2]] update [[0, -1], [1, 1/2*w + 1/2]] | norms=(5, 3)
# #112 matrix [[1, -1/2*w - 1/2], [-1/2*w + 1/2, -2]] update [[0, -1], [1, 1/2*w - 1/2]] | norms=(4, 3)
# #113 matrix [[1, 1/2*w - 1/2], [-1, -1/2*w + 3/2]] update [[1, -1], [0, 1]] | norms=(5, 1)
# #114 matrix [[1, 1/2*w - 1/2], [1, 1/2*w + 1/2]] update [[-1, -1], [0, -1]] | norms=(3, 1)
# #115 matrix [[1, 1/2*w - 1/2], [1/2*w - 1/2, -1/2*w - 3/2]] update [[0, -1], [1, -1/2*w + 1/2]] | norms=(5, 3)
# #116 matrix [[1, 1/2*w - 1/2], [1/2*w + 1/2, -2]] update [[0, -1], [1, -1/2*w - 1/2]] | norms=(4, 3)
# #117 matrix [[1, -1/2*w + 1/2], [-1, 1/2*w + 1/2]] update [[1, -1], [0, 1]] | norms=(3, 1)
# #118 matrix [[1, -1/2*w + 1/2], [1, -1/2*w + 3/2]] update [[-1, -1], [0, -1]] | norms=(5, 1)
# #119 matrix [[1, -1/2*w + 1/2], [-1/2*w - 1/2, -2]] update [[0, -1], [1, 1/2*w + 1/2]] | norms=(4, 3)
# #120 matrix [[1, -1/2*w + 1/2], [-1/2*w + 1/2, -1/2*w - 3/2]] update [[0, -1], [1, 1/2*w - 1/2]] | norms=(5, 3)
# #121 matrix [[1, 1/2*w + 1/2], [-1, -1/2*w + 1/2]] update [[1, -1], [0, 1]] | norms=(3, 1)
# #122 matrix [[1, 1/2*w + 1/2], [1, 1/2*w + 3/2]] update [[-1, -1], [0, -1]] | norms=(5, 1)
# #123 matrix [[1, 1/2*w + 1/2], [1/2*w - 1/2, -2]] update [[0, -1], [1, -1/2*w + 1/2]] | norms=(4, 3)
# #124 matrix [[1, 1/2*w + 1/2], [1/2*w + 1/2, 1/2*w - 3/2]] update [[0, -1], [1, -1/2*w - 1/2]] | norms=(5, 3)
# #125 matrix [[1, -2], [1, -1]] update [[-1, -1], [0, -1]] | norms=(4, 1)
# #126 matrix [[1, 2], [-1, -1]] update [[1, -1], [0, 1]] | norms=(4, 1)
# #127 matrix [[1, -1/2*w - 3/2], [1, -1/2*w - 1/2]] update [[-1, -1], [0, -1]] | norms=(5, 1)
# #128 matrix [[1, 1/2*w - 3/2], [1, 1/2*w - 1/2]] update [[-1, -1], [0, -1]] | norms=(5, 1)
# #129 matrix [[1, -1/2*w + 3/2], [-1, 1/2*w - 1/2]] update [[1, -1], [0, 1]] | norms=(5, 1)
# #130 matrix [[1, 1/2*w + 3/2], [-1, -1/2*w - 1/2]] update [[1, -1], [0, 1]] | norms=(5, 1)
# #131 matrix [[-1/2*w - 1/2, -1], [1, 0]] update [[-1, 1/2*w + 1/2], [0, -1]] | norms=(3, 3)
# #132 matrix [[-1/2*w - 1/2, -1], [-1/2*w + 1/2, -1]] update [[-1, 1/2*w + 1/2], [-1, 1/2*w - 1/2]] | norms=(3, 3)
# #133 matrix [[-1/2*w - 1/2, -1], [-2, 1/2*w - 1/2]] update [[2, 1/2*w + 1/2], [-1/2*w + 1/2, 2]] | norms=(4, 4)
# #134 matrix [[-1/2*w - 1/2, -1], [1/2*w - 3/2, 1/2*w + 1/2]] update [[-1, 1/2*w + 1/2], [1/2*w + 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #135 matrix [[-1/2*w - 1/2, -1], [1/2*w + 3/2, 1]] update [[-1, 1/2*w + 1/2], [1, -1/2*w - 3/2]] | norms=(5, 5)
# #136 matrix [[-1/2*w - 1/2, 1], [-1, 0]] update [[1, 1/2*w + 1/2], [0, 1]] | norms=(3, 3)
# #137 matrix [[-1/2*w - 1/2, 1], [1/2*w - 1/2, -1]] update [[1, 1/2*w + 1/2], [-1, -1/2*w + 1/2]] | norms=(3, 3)
# #138 matrix [[-1/2*w - 1/2, 1], [2, 1/2*w - 1/2]] update [[1, 1/2*w + 1/2], [1/2*w - 1/2, -2]] | norms=(4, 4)
# #139 matrix [[-1/2*w - 1/2, 1], [-1/2*w - 3/2, 1]] update [[1, 1/2*w + 1/2], [1, 1/2*w + 3/2]] | norms=(5, 5)
# #140 matrix [[-1/2*w - 1/2, 1], [-1/2*w + 3/2, 1/2*w + 1/2]] update [[1, 1/2*w + 1/2], [1/2*w + 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #141 matrix [[-1/2*w - 1/2, 1/2*w - 1/2], [1, -1]] update [[-1, 1/2*w + 1/2], [0, -1]] | norms=(3, 3)
# #142 matrix [[-1/2*w - 1/2, 1/2*w - 1/2], [-1/2*w + 1/2, 1/2*w - 3/2]] update [[-1, 1/2*w + 1/2], [-1, 1/2*w - 1/2]] | norms=(5, 3)
# #143 matrix [[-1/2*w - 1/2, 1/2*w - 1/2], [-2, 1/2*w + 3/2]] update [[2, 1/2*w + 1/2], [-1/2*w + 1/2, 2]] | norms=(5, 4)
# #144 matrix [[-1/2*w - 1/2, 1/2*w - 1/2], [1/2*w - 3/2, 2]] update [[-1, 1/2*w + 1/2], [1/2*w + 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #145 matrix [[-1/2*w - 1/2, 1/2*w - 1/2], [1/2*w + 3/2, -1/2*w - 1/2]] update [[-1, 1/2*w + 1/2], [1, -1/2*w - 3/2]] | norms=(5, 5)
# #146 matrix [[-1/2*w - 1/2, -1/2*w + 1/2], [-1, -1]] update [[1, 1/2*w + 1/2], [0, 1]] | norms=(3, 3)
# #147 matrix [[-1/2*w - 1/2, -1/2*w + 1/2], [1/2*w - 1/2, 1/2*w - 3/2]] update [[1, 1/2*w + 1/2], [-1, -1/2*w + 1/2]] | norms=(5, 3)
# #148 matrix [[-1/2*w - 1/2, -1/2*w + 1/2], [2, 1/2*w + 3/2]] update [[1, 1/2*w + 1/2], [1/2*w - 1/2, -2]] | norms=(5, 4)
# #149 matrix [[-1/2*w - 1/2, -1/2*w + 1/2], [-1/2*w - 3/2, -1/2*w - 1/2]] update [[1, 1/2*w + 1/2], [1, 1/2*w + 3/2]] | norms=(5, 5)
# #150 matrix [[-1/2*w - 1/2, -1/2*w + 1/2], [-1/2*w + 3/2, 2]] update [[1, 1/2*w + 1/2], [1/2*w + 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #151 matrix [[-1/2*w - 1/2, -2], [-1, 1/2*w - 1/2]] update [[1, 1/2*w + 1/2], [0, 1]] | norms=(4, 3)
# #152 matrix [[-1/2*w - 1/2, -2], [1/2*w - 1/2, 1/2*w + 3/2]] update [[1, 1/2*w + 1/2], [-1, -1/2*w + 1/2]] | norms=(5, 3)
# #153 matrix [[-1/2*w - 1/2, -2], [2, -1/2*w + 1/2]] update [[1, 1/2*w + 1/2], [1/2*w - 1/2, -2]] | norms=(4, 4)
# #154 matrix [[-1/2*w - 1/2, -2], [-1/2*w + 3/2, -1/2*w - 3/2]] update [[1, 1/2*w + 1/2], [1/2*w + 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #155 matrix [[-1/2*w - 1/2, 2], [1, 1/2*w - 1/2]] update [[-1, 1/2*w + 1/2], [0, -1]] | norms=(4, 3)
# #156 matrix [[-1/2*w - 1/2, 2], [-1/2*w + 1/2, 1/2*w + 3/2]] update [[-1, 1/2*w + 1/2], [-1, 1/2*w - 1/2]] | norms=(5, 3)
# #157 matrix [[-1/2*w - 1/2, 2], [-2, -1/2*w + 1/2]] update [[2, 1/2*w + 1/2], [-1/2*w + 1/2, 2]] | norms=(4, 4)
# #158 matrix [[-1/2*w - 1/2, 2], [1/2*w - 3/2, -1/2*w - 3/2]] update [[-1, 1/2*w + 1/2], [1/2*w + 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #159 matrix [[-1/2*w - 1/2, -1/2*w - 3/2], [1, 1]] update [[-1, 1/2*w + 1/2], [0, -1]] | norms=(5, 3)
# #160 matrix [[-1/2*w - 1/2, -1/2*w - 3/2], [-1/2*w + 1/2, -1/2*w - 1/2]] update [[-1, 1/2*w + 1/2], [-1, 1/2*w - 1/2]] | norms=(5, 3)
# #161 matrix [[-1/2*w - 1/2, 1/2*w - 3/2], [-1, 1/2*w + 1/2]] update [[1, 1/2*w + 1/2], [0, 1]] | norms=(5, 3)
# #162 matrix [[-1/2*w - 1/2, 1/2*w - 3/2], [1/2*w - 1/2, 2]] update [[1, 1/2*w + 1/2], [-1, -1/2*w + 1/2]] | norms=(5, 3)
# #163 matrix [[-1/2*w - 1/2, 1/2*w - 3/2], [2, -1/2*w - 3/2]] update [[1, 1/2*w + 1/2], [1/2*w - 1/2, -2]] | norms=(5, 4)
# #164 matrix [[-1/2*w - 1/2, -1/2*w + 3/2], [1, 1/2*w + 1/2]] update [[-1, 1/2*w + 1/2], [0, -1]] | norms=(5, 3)
# #165 matrix [[-1/2*w - 1/2, -1/2*w + 3/2], [-1/2*w + 1/2, 2]] update [[-1, 1/2*w + 1/2], [-1, 1/2*w - 1/2]] | norms=(5, 3)
# #166 matrix [[-1/2*w - 1/2, -1/2*w + 3/2], [-2, -1/2*w - 3/2]] update [[2, 1/2*w + 1/2], [-1/2*w + 1/2, 2]] | norms=(5, 4)
# #167 matrix [[-1/2*w - 1/2, 1/2*w + 3/2], [-1, 1]] update [[1, 1/2*w + 1/2], [0, 1]] | norms=(5, 3)
# #168 matrix [[-1/2*w - 1/2, 1/2*w + 3/2], [1/2*w - 1/2, -1/2*w - 1/2]] update [[1, 1/2*w + 1/2], [-1, -1/2*w + 1/2]] | norms=(5, 3)
# #169 matrix [[1/2*w - 1/2, -1], [1, 0]] update [[-1, -1/2*w + 1/2], [0, -1]] | norms=(3, 3)
# #170 matrix [[1/2*w - 1/2, -1], [1/2*w + 1/2, -1]] update [[-1, -1/2*w + 1/2], [-1, -1/2*w - 1/2]] | norms=(3, 3)
# #171 matrix [[1/2*w - 1/2, -1], [-2, -1/2*w - 1/2]] update [[2, -1/2*w + 1/2], [1/2*w + 1/2, 2]] | norms=(4, 4)
# #172 matrix [[1/2*w - 1/2, -1], [-1/2*w - 3/2, -1/2*w + 1/2]] update [[-1, -1/2*w + 1/2], [-1/2*w + 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #173 matrix [[1/2*w - 1/2, -1], [-1/2*w + 3/2, 1]] update [[-1, -1/2*w + 1/2], [1, 1/2*w - 3/2]] | norms=(5, 5)
# #174 matrix [[1/2*w - 1/2, 1], [-1, 0]] update [[1, -1/2*w + 1/2], [0, 1]] | norms=(3, 3)
# #175 matrix [[1/2*w - 1/2, 1], [-1/2*w - 1/2, -1]] update [[1, -1/2*w + 1/2], [-1, 1/2*w + 1/2]] | norms=(3, 3)
# #176 matrix [[1/2*w - 1/2, 1], [2, -1/2*w - 1/2]] update [[1, -1/2*w + 1/2], [-1/2*w - 1/2, -2]] | norms=(4, 4)
# #177 matrix [[1/2*w - 1/2, 1], [1/2*w - 3/2, 1]] update [[1, -1/2*w + 1/2], [1, -1/2*w + 3/2]] | norms=(5, 5)
# #178 matrix [[1/2*w - 1/2, 1], [1/2*w + 3/2, -1/2*w + 1/2]] update [[1, -1/2*w + 1/2], [-1/2*w + 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #179 matrix [[1/2*w - 1/2, -1/2*w - 1/2], [1, -1]] update [[-1, -1/2*w + 1/2], [0, -1]] | norms=(3, 3)
# #180 matrix [[1/2*w - 1/2, -1/2*w - 1/2], [1/2*w + 1/2, -1/2*w - 3/2]] update [[-1, -1/2*w + 1/2], [-1, -1/2*w - 1/2]] | norms=(5, 3)
# #181 matrix [[1/2*w - 1/2, -1/2*w - 1/2], [-2, -1/2*w + 3/2]] update [[2, -1/2*w + 1/2], [1/2*w + 1/2, 2]] | norms=(5, 4)
# #182 matrix [[1/2*w - 1/2, -1/2*w - 1/2], [-1/2*w - 3/2, 2]] update [[-1, -1/2*w + 1/2], [-1/2*w + 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #183 matrix [[1/2*w - 1/2, -1/2*w - 1/2], [-1/2*w + 3/2, 1/2*w - 1/2]] update [[-1, -1/2*w + 1/2], [1, 1/2*w - 3/2]] | norms=(5, 5)
# #184 matrix [[1/2*w - 1/2, 1/2*w + 1/2], [-1, -1]] update [[1, -1/2*w + 1/2], [0, 1]] | norms=(3, 3)
# #185 matrix [[1/2*w - 1/2, 1/2*w + 1/2], [-1/2*w - 1/2, -1/2*w - 3/2]] update [[1, -1/2*w + 1/2], [-1, 1/2*w + 1/2]] | norms=(5, 3)
# #186 matrix [[1/2*w - 1/2, 1/2*w + 1/2], [2, -1/2*w + 3/2]] update [[1, -1/2*w + 1/2], [-1/2*w - 1/2, -2]] | norms=(5, 4)
# #187 matrix [[1/2*w - 1/2, 1/2*w + 1/2], [1/2*w - 3/2, 1/2*w - 1/2]] update [[1, -1/2*w + 1/2], [1, -1/2*w + 3/2]] | norms=(5, 5)
# #188 matrix [[1/2*w - 1/2, 1/2*w + 1/2], [1/2*w + 3/2, 2]] update [[1, -1/2*w + 1/2], [-1/2*w + 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #189 matrix [[1/2*w - 1/2, -2], [-1, -1/2*w - 1/2]] update [[1, -1/2*w + 1/2], [0, 1]] | norms=(4, 3)
# #190 matrix [[1/2*w - 1/2, -2], [-1/2*w - 1/2, -1/2*w + 3/2]] update [[1, -1/2*w + 1/2], [-1, 1/2*w + 1/2]] | norms=(5, 3)
# #191 matrix [[1/2*w - 1/2, -2], [2, 1/2*w + 1/2]] update [[1, -1/2*w + 1/2], [-1/2*w - 1/2, -2]] | norms=(4, 4)
# #192 matrix [[1/2*w - 1/2, -2], [1/2*w + 3/2, 1/2*w - 3/2]] update [[1, -1/2*w + 1/2], [-1/2*w + 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #193 matrix [[1/2*w - 1/2, 2], [1, -1/2*w - 1/2]] update [[-1, -1/2*w + 1/2], [0, -1]] | norms=(4, 3)
# #194 matrix [[1/2*w - 1/2, 2], [1/2*w + 1/2, -1/2*w + 3/2]] update [[-1, -1/2*w + 1/2], [-1, -1/2*w - 1/2]] | norms=(5, 3)
# #195 matrix [[1/2*w - 1/2, 2], [-2, 1/2*w + 1/2]] update [[2, -1/2*w + 1/2], [1/2*w + 1/2, 2]] | norms=(4, 4)
# #196 matrix [[1/2*w - 1/2, 2], [-1/2*w - 3/2, 1/2*w - 3/2]] update [[-1, -1/2*w + 1/2], [-1/2*w + 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #197 matrix [[1/2*w - 1/2, -1/2*w - 3/2], [-1, -1/2*w + 1/2]] update [[1, -1/2*w + 1/2], [0, 1]] | norms=(5, 3)
# #198 matrix [[1/2*w - 1/2, -1/2*w - 3/2], [-1/2*w - 1/2, 2]] update [[1, -1/2*w + 1/2], [-1, 1/2*w + 1/2]] | norms=(5, 3)
# #199 matrix [[1/2*w - 1/2, -1/2*w - 3/2], [2, 1/2*w - 3/2]] update [[1, -1/2*w + 1/2], [-1/2*w - 1/2, -2]] | norms=(5, 4)
# #200 matrix [[1/2*w - 1/2, 1/2*w - 3/2], [1, 1]] update [[-1, -1/2*w + 1/2], [0, -1]] | norms=(5, 3)
# #201 matrix [[1/2*w - 1/2, 1/2*w - 3/2], [1/2*w + 1/2, 1/2*w - 1/2]] update [[-1, -1/2*w + 1/2], [-1, -1/2*w - 1/2]] | norms=(5, 3)
# #202 matrix [[1/2*w - 1/2, -1/2*w + 3/2], [-1, 1]] update [[1, -1/2*w + 1/2], [0, 1]] | norms=(5, 3)
# #203 matrix [[1/2*w - 1/2, -1/2*w + 3/2], [-1/2*w - 1/2, 1/2*w - 1/2]] update [[1, -1/2*w + 1/2], [-1, 1/2*w + 1/2]] | norms=(5, 3)
# #204 matrix [[1/2*w - 1/2, 1/2*w + 3/2], [1, -1/2*w + 1/2]] update [[-1, -1/2*w + 1/2], [0, -1]] | norms=(5, 3)
# #205 matrix [[1/2*w - 1/2, 1/2*w + 3/2], [1/2*w + 1/2, 2]] update [[-1, -1/2*w + 1/2], [-1, -1/2*w - 1/2]] | norms=(5, 3)
# #206 matrix [[1/2*w - 1/2, 1/2*w + 3/2], [-2, 1/2*w - 3/2]] update [[2, -1/2*w + 1/2], [1/2*w + 1/2, 2]] | norms=(5, 4)
# #207 matrix [[-1/2*w + 1/2, -1], [1, 0]] update [[-1, 1/2*w - 1/2], [0, -1]] | norms=(3, 3)
# #208 matrix [[-1/2*w + 1/2, -1], [1/2*w + 1/2, 1]] update [[-1, 1/2*w - 1/2], [1, -1/2*w - 1/2]] | norms=(3, 3)
# #209 matrix [[-1/2*w + 1/2, -1], [-2, 1/2*w + 1/2]] update [[-1, 1/2*w - 1/2], [1/2*w + 1/2, 2]] | norms=(4, 4)
# #210 matrix [[-1/2*w + 1/2, -1], [-1/2*w - 3/2, 1/2*w - 1/2]] update [[-1, 1/2*w - 1/2], [1/2*w - 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #211 matrix [[-1/2*w + 1/2, -1], [-1/2*w + 3/2, -1]] update [[-1, 1/2*w - 1/2], [-1, 1/2*w - 3/2]] | norms=(5, 5)
# #212 matrix [[-1/2*w + 1/2, 1], [-1, 0]] update [[1, 1/2*w - 1/2], [0, 1]] | norms=(3, 3)
# #213 matrix [[-1/2*w + 1/2, 1], [-1/2*w - 1/2, 1]] update [[1, 1/2*w - 1/2], [1, 1/2*w + 1/2]] | norms=(3, 3)
# #214 matrix [[-1/2*w + 1/2, 1], [2, 1/2*w + 1/2]] update [[-2, 1/2*w - 1/2], [-1/2*w - 1/2, -2]] | norms=(4, 4)
# #215 matrix [[-1/2*w + 1/2, 1], [1/2*w - 3/2, -1]] update [[1, 1/2*w - 1/2], [-1, -1/2*w + 3/2]] | norms=(5, 5)
# #216 matrix [[-1/2*w + 1/2, 1], [1/2*w + 3/2, 1/2*w - 1/2]] update [[1, 1/2*w - 1/2], [1/2*w - 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #217 matrix [[-1/2*w + 1/2, -1/2*w - 1/2], [1, 1]] update [[-1, 1/2*w - 1/2], [0, -1]] | norms=(3, 3)
# #218 matrix [[-1/2*w + 1/2, -1/2*w - 1/2], [1/2*w + 1/2, 1/2*w + 3/2]] update [[-1, 1/2*w - 1/2], [1, -1/2*w - 1/2]] | norms=(5, 3)
# #219 matrix [[-1/2*w + 1/2, -1/2*w - 1/2], [-2, 1/2*w - 3/2]] update [[-1, 1/2*w - 1/2], [1/2*w + 1/2, 2]] | norms=(5, 4)
# #220 matrix [[-1/2*w + 1/2, -1/2*w - 1/2], [-1/2*w - 3/2, -2]] update [[-1, 1/2*w - 1/2], [1/2*w - 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #221 matrix [[-1/2*w + 1/2, -1/2*w - 1/2], [-1/2*w + 3/2, -1/2*w + 1/2]] update [[-1, 1/2*w - 1/2], [-1, 1/2*w - 3/2]] | norms=(5, 5)
# #222 matrix [[-1/2*w + 1/2, 1/2*w + 1/2], [-1, 1]] update [[1, 1/2*w - 1/2], [0, 1]] | norms=(3, 3)
# #223 matrix [[-1/2*w + 1/2, 1/2*w + 1/2], [-1/2*w - 1/2, 1/2*w + 3/2]] update [[1, 1/2*w - 1/2], [1, 1/2*w + 1/2]] | norms=(5, 3)
# #224 matrix [[-1/2*w + 1/2, 1/2*w + 1/2], [2, 1/2*w - 3/2]] update [[-2, 1/2*w - 1/2], [-1/2*w - 1/2, -2]] | norms=(5, 4)
# #225 matrix [[-1/2*w + 1/2, 1/2*w + 1/2], [1/2*w - 3/2, -1/2*w + 1/2]] update [[1, 1/2*w - 1/2], [-1, -1/2*w + 3/2]] | norms=(5, 5)
# #226 matrix [[-1/2*w + 1/2, 1/2*w + 1/2], [1/2*w + 3/2, -2]] update [[1, 1/2*w - 1/2], [1/2*w - 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #227 matrix [[-1/2*w + 1/2, -2], [-1, 1/2*w + 1/2]] update [[1, 1/2*w - 1/2], [0, 1]] | norms=(4, 3)
# #228 matrix [[-1/2*w + 1/2, -2], [-1/2*w - 1/2, 1/2*w - 3/2]] update [[1, 1/2*w - 1/2], [1, 1/2*w + 1/2]] | norms=(5, 3)
# #229 matrix [[-1/2*w + 1/2, -2], [2, -1/2*w - 1/2]] update [[-2, 1/2*w - 1/2], [-1/2*w - 1/2, -2]] | norms=(4, 4)
# #230 matrix [[-1/2*w + 1/2, -2], [1/2*w + 3/2, -1/2*w + 3/2]] update [[1, 1/2*w - 1/2], [1/2*w - 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #231 matrix [[-1/2*w + 1/2, 2], [1, 1/2*w + 1/2]] update [[-1, 1/2*w - 1/2], [0, -1]] | norms=(4, 3)
# #232 matrix [[-1/2*w + 1/2, 2], [1/2*w + 1/2, 1/2*w - 3/2]] update [[-1, 1/2*w - 1/2], [1, -1/2*w - 1/2]] | norms=(5, 3)
# #233 matrix [[-1/2*w + 1/2, 2], [-2, -1/2*w - 1/2]] update [[-1, 1/2*w - 1/2], [1/2*w + 1/2, 2]] | norms=(4, 4)
# #234 matrix [[-1/2*w + 1/2, 2], [-1/2*w - 3/2, -1/2*w + 3/2]] update [[-1, 1/2*w - 1/2], [1/2*w - 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #235 matrix [[-1/2*w + 1/2, -1/2*w - 3/2], [-1, 1/2*w - 1/2]] update [[1, 1/2*w - 1/2], [0, 1]] | norms=(5, 3)
# #236 matrix [[-1/2*w + 1/2, -1/2*w - 3/2], [-1/2*w - 1/2, -2]] update [[1, 1/2*w - 1/2], [1, 1/2*w + 1/2]] | norms=(5, 3)
# #237 matrix [[-1/2*w + 1/2, -1/2*w - 3/2], [2, -1/2*w + 3/2]] update [[-2, 1/2*w - 1/2], [-1/2*w - 1/2, -2]] | norms=(5, 4)
# #238 matrix [[-1/2*w + 1/2, 1/2*w - 3/2], [1, -1]] update [[-1, 1/2*w - 1/2], [0, -1]] | norms=(5, 3)
# #239 matrix [[-1/2*w + 1/2, 1/2*w - 3/2], [1/2*w + 1/2, -1/2*w + 1/2]] update [[-1, 1/2*w - 1/2], [1, -1/2*w - 1/2]] | norms=(5, 3)
# #240 matrix [[-1/2*w + 1/2, -1/2*w + 3/2], [-1, -1]] update [[1, 1/2*w - 1/2], [0, 1]] | norms=(5, 3)
# #241 matrix [[-1/2*w + 1/2, -1/2*w + 3/2], [-1/2*w - 1/2, -1/2*w + 1/2]] update [[1, 1/2*w - 1/2], [1, 1/2*w + 1/2]] | norms=(5, 3)
# #242 matrix [[-1/2*w + 1/2, 1/2*w + 3/2], [1, 1/2*w - 1/2]] update [[-1, 1/2*w - 1/2], [0, -1]] | norms=(5, 3)
# #243 matrix [[-1/2*w + 1/2, 1/2*w + 3/2], [1/2*w + 1/2, -2]] update [[-1, 1/2*w - 1/2], [1, -1/2*w - 1/2]] | norms=(5, 3)
# #244 matrix [[-1/2*w + 1/2, 1/2*w + 3/2], [-2, -1/2*w + 3/2]] update [[-1, 1/2*w - 1/2], [1/2*w + 1/2, 2]] | norms=(5, 4)
# #245 matrix [[1/2*w + 1/2, -1], [1, 0]] update [[-1, -1/2*w - 1/2], [0, -1]] | norms=(3, 3)
# #246 matrix [[1/2*w + 1/2, -1], [-1/2*w + 1/2, 1]] update [[-1, -1/2*w - 1/2], [1, 1/2*w - 1/2]] | norms=(3, 3)
# #247 matrix [[1/2*w + 1/2, -1], [-2, -1/2*w + 1/2]] update [[-1, -1/2*w - 1/2], [-1/2*w + 1/2, 2]] | norms=(4, 4)
# #248 matrix [[1/2*w + 1/2, -1], [1/2*w - 3/2, -1/2*w - 1/2]] update [[-1, -1/2*w - 1/2], [-1/2*w - 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #249 matrix [[1/2*w + 1/2, -1], [1/2*w + 3/2, -1]] update [[-1, -1/2*w - 1/2], [-1, -1/2*w - 3/2]] | norms=(5, 5)
# #250 matrix [[1/2*w + 1/2, 1], [-1, 0]] update [[1, -1/2*w - 1/2], [0, 1]] | norms=(3, 3)
# #251 matrix [[1/2*w + 1/2, 1], [1/2*w - 1/2, 1]] update [[1, -1/2*w - 1/2], [1, -1/2*w + 1/2]] | norms=(3, 3)
# #252 matrix [[1/2*w + 1/2, 1], [2, -1/2*w + 1/2]] update [[-2, -1/2*w - 1/2], [1/2*w - 1/2, -2]] | norms=(4, 4)
# #253 matrix [[1/2*w + 1/2, 1], [-1/2*w - 3/2, -1]] update [[1, -1/2*w - 1/2], [-1, 1/2*w + 3/2]] | norms=(5, 5)
# #254 matrix [[1/2*w + 1/2, 1], [-1/2*w + 3/2, -1/2*w - 1/2]] update [[1, -1/2*w - 1/2], [-1/2*w - 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #255 matrix [[1/2*w + 1/2, 1/2*w - 1/2], [1, 1]] update [[-1, -1/2*w - 1/2], [0, -1]] | norms=(3, 3)
# #256 matrix [[1/2*w + 1/2, 1/2*w - 1/2], [-1/2*w + 1/2, -1/2*w + 3/2]] update [[-1, -1/2*w - 1/2], [1, 1/2*w - 1/2]] | norms=(5, 3)
# #257 matrix [[1/2*w + 1/2, 1/2*w - 1/2], [-2, -1/2*w - 3/2]] update [[-1, -1/2*w - 1/2], [-1/2*w + 1/2, 2]] | norms=(5, 4)
# #258 matrix [[1/2*w + 1/2, 1/2*w - 1/2], [1/2*w - 3/2, -2]] update [[-1, -1/2*w - 1/2], [-1/2*w - 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #259 matrix [[1/2*w + 1/2, 1/2*w - 1/2], [1/2*w + 3/2, 1/2*w + 1/2]] update [[-1, -1/2*w - 1/2], [-1, -1/2*w - 3/2]] | norms=(5, 5)
# #260 matrix [[1/2*w + 1/2, -1/2*w + 1/2], [-1, 1]] update [[1, -1/2*w - 1/2], [0, 1]] | norms=(3, 3)
# #261 matrix [[1/2*w + 1/2, -1/2*w + 1/2], [1/2*w - 1/2, -1/2*w + 3/2]] update [[1, -1/2*w - 1/2], [1, -1/2*w + 1/2]] | norms=(5, 3)
# #262 matrix [[1/2*w + 1/2, -1/2*w + 1/2], [2, -1/2*w - 3/2]] update [[-2, -1/2*w - 1/2], [1/2*w - 1/2, -2]] | norms=(5, 4)
# #263 matrix [[1/2*w + 1/2, -1/2*w + 1/2], [-1/2*w - 3/2, 1/2*w + 1/2]] update [[1, -1/2*w - 1/2], [-1, 1/2*w + 3/2]] | norms=(5, 5)
# #264 matrix [[1/2*w + 1/2, -1/2*w + 1/2], [-1/2*w + 3/2, -2]] update [[1, -1/2*w - 1/2], [-1/2*w - 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #265 matrix [[1/2*w + 1/2, -2], [-1, -1/2*w + 1/2]] update [[1, -1/2*w - 1/2], [0, 1]] | norms=(4, 3)
# #266 matrix [[1/2*w + 1/2, -2], [1/2*w - 1/2, -1/2*w - 3/2]] update [[1, -1/2*w - 1/2], [1, -1/2*w + 1/2]] | norms=(5, 3)
# #267 matrix [[1/2*w + 1/2, -2], [2, 1/2*w - 1/2]] update [[-2, -1/2*w - 1/2], [1/2*w - 1/2, -2]] | norms=(4, 4)
# #268 matrix [[1/2*w + 1/2, -2], [-1/2*w + 3/2, 1/2*w + 3/2]] update [[1, -1/2*w - 1/2], [-1/2*w - 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #269 matrix [[1/2*w + 1/2, 2], [1, -1/2*w + 1/2]] update [[-1, -1/2*w - 1/2], [0, -1]] | norms=(4, 3)
# #270 matrix [[1/2*w + 1/2, 2], [-1/2*w + 1/2, -1/2*w - 3/2]] update [[-1, -1/2*w - 1/2], [1, 1/2*w - 1/2]] | norms=(5, 3)
# #271 matrix [[1/2*w + 1/2, 2], [-2, 1/2*w - 1/2]] update [[-1, -1/2*w - 1/2], [-1/2*w + 1/2, 2]] | norms=(4, 4)
# #272 matrix [[1/2*w + 1/2, 2], [1/2*w - 3/2, 1/2*w + 3/2]] update [[-1, -1/2*w - 1/2], [-1/2*w - 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #273 matrix [[1/2*w + 1/2, -1/2*w - 3/2], [1, -1]] update [[-1, -1/2*w - 1/2], [0, -1]] | norms=(5, 3)
# #274 matrix [[1/2*w + 1/2, -1/2*w - 3/2], [-1/2*w + 1/2, 1/2*w + 1/2]] update [[-1, -1/2*w - 1/2], [1, 1/2*w - 1/2]] | norms=(5, 3)
# #275 matrix [[1/2*w + 1/2, 1/2*w - 3/2], [-1, -1/2*w - 1/2]] update [[1, -1/2*w - 1/2], [0, 1]] | norms=(5, 3)
# #276 matrix [[1/2*w + 1/2, 1/2*w - 3/2], [1/2*w - 1/2, -2]] update [[1, -1/2*w - 1/2], [1, -1/2*w + 1/2]] | norms=(5, 3)
# #277 matrix [[1/2*w + 1/2, 1/2*w - 3/2], [2, 1/2*w + 3/2]] update [[-2, -1/2*w - 1/2], [1/2*w - 1/2, -2]] | norms=(5, 4)
# #278 matrix [[1/2*w + 1/2, -1/2*w + 3/2], [1, -1/2*w - 1/2]] update [[-1, -1/2*w - 1/2], [0, -1]] | norms=(5, 3)
# #279 matrix [[1/2*w + 1/2, -1/2*w + 3/2], [-1/2*w + 1/2, -2]] update [[-1, -1/2*w - 1/2], [1, 1/2*w - 1/2]] | norms=(5, 3)
# #280 matrix [[1/2*w + 1/2, -1/2*w + 3/2], [-2, 1/2*w + 3/2]] update [[-1, -1/2*w - 1/2], [-1/2*w + 1/2, 2]] | norms=(5, 4)
# #281 matrix [[1/2*w + 1/2, 1/2*w + 3/2], [-1, -1]] update [[1, -1/2*w - 1/2], [0, 1]] | norms=(5, 3)
# #282 matrix [[1/2*w + 1/2, 1/2*w + 3/2], [1/2*w - 1/2, 1/2*w + 1/2]] update [[1, -1/2*w - 1/2], [1, -1/2*w + 1/2]] | norms=(5, 3)
# #283 matrix [[-2, -1], [-1, -1]] update [[1, 2], [0, 1]] | norms=(4, 4)
# #284 matrix [[-2, -1], [1, 0]] update [[-1, 2], [0, -1]] | norms=(4, 4)
# #285 matrix [[-2, 1], [-1, 0]] update [[1, 2], [0, 1]] | norms=(4, 4)
# #286 matrix [[-2, 1], [1, -1]] update [[-1, 2], [0, -1]] | norms=(4, 4)
# #287 matrix [[-2, -1/2*w - 1/2], [1/2*w - 1/2, -2]] update [[1/2*w + 1/2, 2], [1, -1/2*w + 1/2]] | norms=(4, 4)
# #288 matrix [[-2, -1/2*w - 1/2], [-1/2*w + 1/2, 1]] update [[-1/2*w - 1/2, 2], [1, 1/2*w - 1/2]] | norms=(4, 4)
# #289 matrix [[-2, -1/2*w - 1/2], [-1/2*w - 3/2, -1/2*w + 1/2]] update [[-1/2*w - 1/2, 2], [-1/2*w + 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #290 matrix [[-2, -1/2*w - 1/2], [1/2*w + 3/2, 1/2*w - 3/2]] update [[1/2*w + 1/2, 2], [-1/2*w + 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #291 matrix [[-2, 1/2*w - 1/2], [-1/2*w - 1/2, -2]] update [[-1/2*w + 1/2, 2], [1, 1/2*w + 1/2]] | norms=(4, 4)
# #292 matrix [[-2, 1/2*w - 1/2], [1/2*w + 1/2, 1]] update [[1/2*w - 1/2, 2], [1, -1/2*w - 1/2]] | norms=(4, 4)
# #293 matrix [[-2, 1/2*w - 1/2], [1/2*w - 3/2, 1/2*w + 1/2]] update [[1/2*w - 1/2, 2], [1/2*w + 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #294 matrix [[-2, 1/2*w - 1/2], [-1/2*w + 3/2, -1/2*w - 3/2]] update [[-1/2*w + 1/2, 2], [1/2*w + 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #295 matrix [[-2, -1/2*w + 1/2], [-1/2*w - 1/2, 1]] update [[-1/2*w + 1/2, 2], [1, 1/2*w + 1/2]] | norms=(4, 4)
# #296 matrix [[-2, -1/2*w + 1/2], [1/2*w + 1/2, -2]] update [[1/2*w - 1/2, 2], [1, -1/2*w - 1/2]] | norms=(4, 4)
# #297 matrix [[-2, -1/2*w + 1/2], [1/2*w - 3/2, -1/2*w - 3/2]] update [[1/2*w - 1/2, 2], [1/2*w + 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #298 matrix [[-2, -1/2*w + 1/2], [-1/2*w + 3/2, 1/2*w + 1/2]] update [[-1/2*w + 1/2, 2], [1/2*w + 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #299 matrix [[-2, 1/2*w + 1/2], [1/2*w - 1/2, 1]] update [[1/2*w + 1/2, 2], [1, -1/2*w + 1/2]] | norms=(4, 4)
# #300 matrix [[-2, 1/2*w + 1/2], [-1/2*w + 1/2, -2]] update [[-1/2*w - 1/2, 2], [1, 1/2*w - 1/2]] | norms=(4, 4)
# #301 matrix [[-2, 1/2*w + 1/2], [-1/2*w - 3/2, 1/2*w - 3/2]] update [[-1/2*w - 1/2, 2], [-1/2*w + 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #302 matrix [[-2, 1/2*w + 1/2], [1/2*w + 3/2, -1/2*w + 1/2]] update [[1/2*w + 1/2, 2], [-1/2*w + 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #303 matrix [[-2, -1/2*w - 3/2], [-1/2*w - 1/2, -1/2*w + 1/2]] update [[-1/2*w + 1/2, 2], [1, 1/2*w + 1/2]] | norms=(5, 4)
# #304 matrix [[-2, -1/2*w - 3/2], [1/2*w + 1/2, 1/2*w - 3/2]] update [[1/2*w - 1/2, 2], [1, -1/2*w - 1/2]] | norms=(5, 4)
# #305 matrix [[-2, -1/2*w - 3/2], [-1/2*w + 3/2, 2]] update [[-1/2*w + 1/2, 2], [1/2*w + 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #306 matrix [[-2, 1/2*w - 3/2], [1/2*w - 1/2, 1/2*w + 1/2]] update [[1/2*w + 1/2, 2], [1, -1/2*w + 1/2]] | norms=(5, 4)
# #307 matrix [[-2, 1/2*w - 3/2], [-1/2*w + 1/2, -1/2*w - 3/2]] update [[-1/2*w - 1/2, 2], [1, 1/2*w - 1/2]] | norms=(5, 4)
# #308 matrix [[-2, 1/2*w - 3/2], [1/2*w + 3/2, 2]] update [[1/2*w + 1/2, 2], [-1/2*w + 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #309 matrix [[-2, -1/2*w + 3/2], [1/2*w - 1/2, -1/2*w - 3/2]] update [[1/2*w + 1/2, 2], [1, -1/2*w + 1/2]] | norms=(5, 4)
# #310 matrix [[-2, -1/2*w + 3/2], [-1/2*w + 1/2, 1/2*w + 1/2]] update [[-1/2*w - 1/2, 2], [1, 1/2*w - 1/2]] | norms=(5, 4)
# #311 matrix [[-2, -1/2*w + 3/2], [-1/2*w - 3/2, 2]] update [[-1/2*w - 1/2, 2], [-1/2*w + 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #312 matrix [[-2, 1/2*w + 3/2], [-1/2*w - 1/2, 1/2*w - 3/2]] update [[-1/2*w + 1/2, 2], [1, 1/2*w + 1/2]] | norms=(5, 4)
# #313 matrix [[-2, 1/2*w + 3/2], [1/2*w + 1/2, -1/2*w + 1/2]] update [[1/2*w - 1/2, 2], [1, -1/2*w - 1/2]] | norms=(5, 4)
# #314 matrix [[-2, 1/2*w + 3/2], [1/2*w - 3/2, 2]] update [[1/2*w - 1/2, 2], [1/2*w + 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #315 matrix [[2, -1], [-1, 1]] update [[1, -2], [0, 1]] | norms=(4, 4)
# #316 matrix [[2, -1], [1, 0]] update [[-1, -2], [0, -1]] | norms=(4, 4)
# #317 matrix [[2, 1], [-1, 0]] update [[1, -2], [0, 1]] | norms=(4, 4)
# #318 matrix [[2, 1], [1, 1]] update [[-1, -2], [0, -1]] | norms=(4, 4)
# #319 matrix [[2, -1/2*w - 1/2], [1/2*w - 1/2, 2]] update [[1/2*w + 1/2, -2], [-1, -1/2*w + 1/2]] | norms=(4, 4)
# #320 matrix [[2, -1/2*w - 1/2], [-1/2*w + 1/2, -1]] update [[-1/2*w - 1/2, -2], [-1, 1/2*w - 1/2]] | norms=(4, 4)
# #321 matrix [[2, -1/2*w - 1/2], [-1/2*w - 3/2, 1/2*w - 1/2]] update [[-1/2*w - 1/2, -2], [1/2*w - 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #322 matrix [[2, -1/2*w - 1/2], [1/2*w + 3/2, -1/2*w + 3/2]] update [[1/2*w + 1/2, -2], [1/2*w - 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #323 matrix [[2, 1/2*w - 1/2], [-1/2*w - 1/2, 2]] update [[-1/2*w + 1/2, -2], [-1, 1/2*w + 1/2]] | norms=(4, 4)
# #324 matrix [[2, 1/2*w - 1/2], [1/2*w + 1/2, -1]] update [[1/2*w - 1/2, -2], [-1, -1/2*w - 1/2]] | norms=(4, 4)
# #325 matrix [[2, 1/2*w - 1/2], [1/2*w - 3/2, -1/2*w - 1/2]] update [[1/2*w - 1/2, -2], [-1/2*w - 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #326 matrix [[2, 1/2*w - 1/2], [-1/2*w + 3/2, 1/2*w + 3/2]] update [[-1/2*w + 1/2, -2], [-1/2*w - 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #327 matrix [[2, -1/2*w + 1/2], [-1/2*w - 1/2, -1]] update [[-1/2*w + 1/2, -2], [-1, 1/2*w + 1/2]] | norms=(4, 4)
# #328 matrix [[2, -1/2*w + 1/2], [1/2*w + 1/2, 2]] update [[1/2*w - 1/2, -2], [-1, -1/2*w - 1/2]] | norms=(4, 4)
# #329 matrix [[2, -1/2*w + 1/2], [1/2*w - 3/2, 1/2*w + 3/2]] update [[1/2*w - 1/2, -2], [-1/2*w - 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #330 matrix [[2, -1/2*w + 1/2], [-1/2*w + 3/2, -1/2*w - 1/2]] update [[-1/2*w + 1/2, -2], [-1/2*w - 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #331 matrix [[2, 1/2*w + 1/2], [1/2*w - 1/2, -1]] update [[1/2*w + 1/2, -2], [-1, -1/2*w + 1/2]] | norms=(4, 4)
# #332 matrix [[2, 1/2*w + 1/2], [-1/2*w + 1/2, 2]] update [[-1/2*w - 1/2, -2], [-1, 1/2*w - 1/2]] | norms=(4, 4)
# #333 matrix [[2, 1/2*w + 1/2], [-1/2*w - 3/2, -1/2*w + 3/2]] update [[-1/2*w - 1/2, -2], [1/2*w - 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #334 matrix [[2, 1/2*w + 1/2], [1/2*w + 3/2, 1/2*w - 1/2]] update [[1/2*w + 1/2, -2], [1/2*w - 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #335 matrix [[2, -1/2*w - 3/2], [-1/2*w - 1/2, 1/2*w - 1/2]] update [[-1/2*w + 1/2, -2], [-1, 1/2*w + 1/2]] | norms=(5, 4)
# #336 matrix [[2, -1/2*w - 3/2], [1/2*w + 1/2, -1/2*w + 3/2]] update [[1/2*w - 1/2, -2], [-1, -1/2*w - 1/2]] | norms=(5, 4)
# #337 matrix [[2, -1/2*w - 3/2], [-1/2*w + 3/2, -2]] update [[-1/2*w + 1/2, -2], [-1/2*w - 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #338 matrix [[2, 1/2*w - 3/2], [1/2*w - 1/2, -1/2*w - 1/2]] update [[1/2*w + 1/2, -2], [-1, -1/2*w + 1/2]] | norms=(5, 4)
# #339 matrix [[2, 1/2*w - 3/2], [-1/2*w + 1/2, 1/2*w + 3/2]] update [[-1/2*w - 1/2, -2], [-1, 1/2*w - 1/2]] | norms=(5, 4)
# #340 matrix [[2, 1/2*w - 3/2], [1/2*w + 3/2, -2]] update [[1/2*w + 1/2, -2], [1/2*w - 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #341 matrix [[2, -1/2*w + 3/2], [1/2*w - 1/2, 1/2*w + 3/2]] update [[1/2*w + 1/2, -2], [-1, -1/2*w + 1/2]] | norms=(5, 4)
# #342 matrix [[2, -1/2*w + 3/2], [-1/2*w + 1/2, -1/2*w - 1/2]] update [[-1/2*w - 1/2, -2], [-1, 1/2*w - 1/2]] | norms=(5, 4)
# #343 matrix [[2, -1/2*w + 3/2], [-1/2*w - 3/2, -2]] update [[-1/2*w - 1/2, -2], [1/2*w - 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #344 matrix [[2, 1/2*w + 3/2], [-1/2*w - 1/2, -1/2*w + 3/2]] update [[-1/2*w + 1/2, -2], [-1, 1/2*w + 1/2]] | norms=(5, 4)
# #345 matrix [[2, 1/2*w + 3/2], [1/2*w + 1/2, 1/2*w - 1/2]] update [[1/2*w - 1/2, -2], [-1, -1/2*w - 1/2]] | norms=(5, 4)
# #346 matrix [[2, 1/2*w + 3/2], [1/2*w - 3/2, -2]] update [[1/2*w - 1/2, -2], [-1/2*w - 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #347 matrix [[-1/2*w - 3/2, -1], [1, 0]] update [[-1, 1/2*w + 3/2], [0, -1]] | norms=(5, 5)
# #348 matrix [[-1/2*w - 3/2, -1], [-1/2*w - 1/2, -1]] update [[-1, 1/2*w + 3/2], [-1, 1/2*w + 1/2]] | norms=(5, 5)
# #349 matrix [[-1/2*w - 3/2, 1], [-1, 0]] update [[1, 1/2*w + 3/2], [0, 1]] | norms=(5, 5)
# #350 matrix [[-1/2*w - 3/2, 1], [1/2*w + 1/2, -1]] update [[1, 1/2*w + 3/2], [-1, -1/2*w - 1/2]] | norms=(5, 5)
# #351 matrix [[-1/2*w - 3/2, -1/2*w - 1/2], [-1, -1]] update [[1, 1/2*w + 3/2], [0, 1]] | norms=(5, 5)
# #352 matrix [[-1/2*w - 3/2, -1/2*w - 1/2], [1/2*w + 1/2, 1/2*w - 1/2]] update [[1, 1/2*w + 3/2], [-1, -1/2*w - 1/2]] | norms=(5, 5)
# #353 matrix [[-1/2*w - 3/2, 1/2*w - 1/2], [1/2*w - 1/2, 1]] update [[1/2*w - 1/2, 1/2*w + 3/2], [1, -1/2*w + 1/2]] | norms=(5, 5)
# #354 matrix [[-1/2*w - 3/2, 1/2*w - 1/2], [-2, 1/2*w + 1/2]] update [[1/2*w - 1/2, 1/2*w + 3/2], [1/2*w + 1/2, 2]] | norms=(5, 5)
# #355 matrix [[-1/2*w - 3/2, 1/2*w - 1/2], [-1/2*w + 3/2, -2]] update [[-2, 1/2*w + 3/2], [-1/2*w - 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #356 matrix [[-1/2*w - 3/2, -1/2*w + 1/2], [-1/2*w + 1/2, 1]] update [[-1/2*w + 1/2, 1/2*w + 3/2], [1, 1/2*w - 1/2]] | norms=(5, 5)
# #357 matrix [[-1/2*w - 3/2, -1/2*w + 1/2], [2, 1/2*w + 1/2]] update [[1/2*w - 3/2, 1/2*w + 3/2], [-1/2*w - 1/2, -2]] | norms=(5, 5)
# #358 matrix [[-1/2*w - 3/2, -1/2*w + 1/2], [1/2*w - 3/2, -2]] update [[2, 1/2*w + 3/2], [-1/2*w - 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #359 matrix [[-1/2*w - 3/2, 1/2*w + 1/2], [1, -1]] update [[-1, 1/2*w + 3/2], [0, -1]] | norms=(5, 5)
# #360 matrix [[-1/2*w - 3/2, 1/2*w + 1/2], [-1/2*w - 1/2, 1/2*w - 1/2]] update [[-1, 1/2*w + 3/2], [-1, 1/2*w + 1/2]] | norms=(5, 5)
# #361 matrix [[-1/2*w - 3/2, -2], [1/2*w - 1/2, 1/2*w + 1/2]] update [[1/2*w - 1/2, 1/2*w + 3/2], [1, -1/2*w + 1/2]] | norms=(5, 5)
# #362 matrix [[-1/2*w - 3/2, -2], [-2, 1/2*w - 3/2]] update [[1/2*w - 1/2, 1/2*w + 3/2], [1/2*w + 1/2, 2]] | norms=(5, 5)
# #363 matrix [[-1/2*w - 3/2, -2], [-1/2*w + 3/2, -1/2*w - 1/2]] update [[-2, 1/2*w + 3/2], [-1/2*w - 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #364 matrix [[-1/2*w - 3/2, 2], [-1/2*w + 1/2, 1/2*w + 1/2]] update [[-1/2*w + 1/2, 1/2*w + 3/2], [1, 1/2*w - 1/2]] | norms=(5, 5)
# #365 matrix [[-1/2*w - 3/2, 2], [2, 1/2*w - 3/2]] update [[1/2*w - 3/2, 1/2*w + 3/2], [-1/2*w - 1/2, -2]] | norms=(5, 5)
# #366 matrix [[-1/2*w - 3/2, 2], [1/2*w - 3/2, -1/2*w - 1/2]] update [[2, 1/2*w + 3/2], [-1/2*w - 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #367 matrix [[-1/2*w - 3/2, 1/2*w - 3/2], [-1/2*w + 1/2, -2]] update [[-1/2*w + 1/2, 1/2*w + 3/2], [1, 1/2*w - 1/2]] | norms=(5, 5)
# #368 matrix [[-1/2*w - 3/2, 1/2*w - 3/2], [2, -1/2*w - 1/2]] update [[1/2*w - 3/2, 1/2*w + 3/2], [-1/2*w - 1/2, -2]] | norms=(5, 5)
# #369 matrix [[-1/2*w - 3/2, 1/2*w - 3/2], [1/2*w - 3/2, 1/2*w + 3/2]] update [[2, 1/2*w + 3/2], [-1/2*w - 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #370 matrix [[-1/2*w - 3/2, -1/2*w + 3/2], [1/2*w - 1/2, -2]] update [[1/2*w - 1/2, 1/2*w + 3/2], [1, -1/2*w + 1/2]] | norms=(5, 5)
# #371 matrix [[-1/2*w - 3/2, -1/2*w + 3/2], [-2, -1/2*w - 1/2]] update [[1/2*w - 1/2, 1/2*w + 3/2], [1/2*w + 1/2, 2]] | norms=(5, 5)
# #372 matrix [[-1/2*w - 3/2, -1/2*w + 3/2], [-1/2*w + 3/2, 1/2*w + 3/2]] update [[-2, 1/2*w + 3/2], [-1/2*w - 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #373 matrix [[1/2*w - 3/2, -1], [1, 0]] update [[-1, -1/2*w + 3/2], [0, -1]] | norms=(5, 5)
# #374 matrix [[1/2*w - 3/2, -1], [1/2*w - 1/2, -1]] update [[-1, -1/2*w + 3/2], [-1, -1/2*w + 1/2]] | norms=(5, 5)
# #375 matrix [[1/2*w - 3/2, 1], [-1, 0]] update [[1, -1/2*w + 3/2], [0, 1]] | norms=(5, 5)
# #376 matrix [[1/2*w - 3/2, 1], [-1/2*w + 1/2, -1]] update [[1, -1/2*w + 3/2], [-1, 1/2*w - 1/2]] | norms=(5, 5)
# #377 matrix [[1/2*w - 3/2, -1/2*w - 1/2], [-1/2*w - 1/2, 1]] update [[-1/2*w - 1/2, -1/2*w + 3/2], [1, 1/2*w + 1/2]] | norms=(5, 5)
# #378 matrix [[1/2*w - 3/2, -1/2*w - 1/2], [-2, -1/2*w + 1/2]] update [[-1/2*w - 1/2, -1/2*w + 3/2], [-1/2*w + 1/2, 2]] | norms=(5, 5)
# #379 matrix [[1/2*w - 3/2, -1/2*w - 1/2], [1/2*w + 3/2, -2]] update [[-2, -1/2*w + 3/2], [1/2*w - 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #380 matrix [[1/2*w - 3/2, 1/2*w - 1/2], [-1, -1]] update [[1, -1/2*w + 3/2], [0, 1]] | norms=(5, 5)
# #381 matrix [[1/2*w - 3/2, 1/2*w - 1/2], [-1/2*w + 1/2, -1/2*w - 1/2]] update [[1, -1/2*w + 3/2], [-1, 1/2*w - 1/2]] | norms=(5, 5)
# #382 matrix [[1/2*w - 3/2, -1/2*w + 1/2], [1, -1]] update [[-1, -1/2*w + 3/2], [0, -1]] | norms=(5, 5)
# #383 matrix [[1/2*w - 3/2, -1/2*w + 1/2], [1/2*w - 1/2, -1/2*w - 1/2]] update [[-1, -1/2*w + 3/2], [-1, -1/2*w + 1/2]] | norms=(5, 5)
# #384 matrix [[1/2*w - 3/2, 1/2*w + 1/2], [1/2*w + 1/2, 1]] update [[1/2*w + 1/2, -1/2*w + 3/2], [1, -1/2*w - 1/2]] | norms=(5, 5)
# #385 matrix [[1/2*w - 3/2, 1/2*w + 1/2], [2, -1/2*w + 1/2]] update [[-1/2*w - 3/2, -1/2*w + 3/2], [1/2*w - 1/2, -2]] | norms=(5, 5)
# #386 matrix [[1/2*w - 3/2, 1/2*w + 1/2], [-1/2*w - 3/2, -2]] update [[2, -1/2*w + 3/2], [1/2*w - 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #387 matrix [[1/2*w - 3/2, -2], [-1/2*w - 1/2, -1/2*w + 1/2]] update [[-1/2*w - 1/2, -1/2*w + 3/2], [1, 1/2*w + 1/2]] | norms=(5, 5)
# #388 matrix [[1/2*w - 3/2, -2], [-2, -1/2*w - 3/2]] update [[-1/2*w - 1/2, -1/2*w + 3/2], [-1/2*w + 1/2, 2]] | norms=(5, 5)
# #389 matrix [[1/2*w - 3/2, -2], [1/2*w + 3/2, 1/2*w - 1/2]] update [[-2, -1/2*w + 3/2], [1/2*w - 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #390 matrix [[1/2*w - 3/2, 2], [1/2*w + 1/2, -1/2*w + 1/2]] update [[1/2*w + 1/2, -1/2*w + 3/2], [1, -1/2*w - 1/2]] | norms=(5, 5)
# #391 matrix [[1/2*w - 3/2, 2], [2, -1/2*w - 3/2]] update [[-1/2*w - 3/2, -1/2*w + 3/2], [1/2*w - 1/2, -2]] | norms=(5, 5)
# #392 matrix [[1/2*w - 3/2, 2], [-1/2*w - 3/2, 1/2*w - 1/2]] update [[2, -1/2*w + 3/2], [1/2*w - 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #393 matrix [[1/2*w - 3/2, -1/2*w - 3/2], [1/2*w + 1/2, -2]] update [[1/2*w + 1/2, -1/2*w + 3/2], [1, -1/2*w - 1/2]] | norms=(5, 5)
# #394 matrix [[1/2*w - 3/2, -1/2*w - 3/2], [2, 1/2*w - 1/2]] update [[-1/2*w - 3/2, -1/2*w + 3/2], [1/2*w - 1/2, -2]] | norms=(5, 5)
# #395 matrix [[1/2*w - 3/2, -1/2*w - 3/2], [-1/2*w - 3/2, -1/2*w + 3/2]] update [[2, -1/2*w + 3/2], [1/2*w - 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #396 matrix [[1/2*w - 3/2, 1/2*w + 3/2], [-1/2*w - 1/2, -2]] update [[-1/2*w - 1/2, -1/2*w + 3/2], [1, 1/2*w + 1/2]] | norms=(5, 5)
# #397 matrix [[1/2*w - 3/2, 1/2*w + 3/2], [-2, 1/2*w - 1/2]] update [[-1/2*w - 1/2, -1/2*w + 3/2], [-1/2*w + 1/2, 2]] | norms=(5, 5)
# #398 matrix [[1/2*w - 3/2, 1/2*w + 3/2], [1/2*w + 3/2, -1/2*w + 3/2]] update [[-2, -1/2*w + 3/2], [1/2*w - 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #399 matrix [[-1/2*w + 3/2, -1], [1, 0]] update [[-1, 1/2*w - 3/2], [0, -1]] | norms=(5, 5)
# #400 matrix [[-1/2*w + 3/2, -1], [1/2*w - 1/2, 1]] update [[-1, 1/2*w - 3/2], [1, -1/2*w + 1/2]] | norms=(5, 5)
# #401 matrix [[-1/2*w + 3/2, 1], [-1, 0]] update [[1, 1/2*w - 3/2], [0, 1]] | norms=(5, 5)
# #402 matrix [[-1/2*w + 3/2, 1], [-1/2*w + 1/2, 1]] update [[1, 1/2*w - 3/2], [1, 1/2*w - 1/2]] | norms=(5, 5)
# #403 matrix [[-1/2*w + 3/2, -1/2*w - 1/2], [-1/2*w - 1/2, -1]] update [[-1/2*w - 1/2, 1/2*w - 3/2], [-1, 1/2*w + 1/2]] | norms=(5, 5)
# #404 matrix [[-1/2*w + 3/2, -1/2*w - 1/2], [-2, 1/2*w - 1/2]] update [[1/2*w + 3/2, 1/2*w - 3/2], [-1/2*w + 1/2, 2]] | norms=(5, 5)
# #405 matrix [[-1/2*w + 3/2, -1/2*w - 1/2], [1/2*w + 3/2, 2]] update [[-2, 1/2*w - 3/2], [-1/2*w + 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #406 matrix [[-1/2*w + 3/2, 1/2*w - 1/2], [-1, 1]] update [[1, 1/2*w - 3/2], [0, 1]] | norms=(5, 5)
# #407 matrix [[-1/2*w + 3/2, 1/2*w - 1/2], [-1/2*w + 1/2, 1/2*w + 1/2]] update [[1, 1/2*w - 3/2], [1, 1/2*w - 1/2]] | norms=(5, 5)
# #408 matrix [[-1/2*w + 3/2, -1/2*w + 1/2], [1, 1]] update [[-1, 1/2*w - 3/2], [0, -1]] | norms=(5, 5)
# #409 matrix [[-1/2*w + 3/2, -1/2*w + 1/2], [1/2*w - 1/2, 1/2*w + 1/2]] update [[-1, 1/2*w - 3/2], [1, -1/2*w + 1/2]] | norms=(5, 5)
# #410 matrix [[-1/2*w + 3/2, 1/2*w + 1/2], [1/2*w + 1/2, -1]] update [[1/2*w + 1/2, 1/2*w - 3/2], [-1, -1/2*w - 1/2]] | norms=(5, 5)
# #411 matrix [[-1/2*w + 3/2, 1/2*w + 1/2], [2, 1/2*w - 1/2]] update [[1/2*w + 1/2, 1/2*w - 3/2], [1/2*w - 1/2, -2]] | norms=(5, 5)
# #412 matrix [[-1/2*w + 3/2, 1/2*w + 1/2], [-1/2*w - 3/2, 2]] update [[2, 1/2*w - 3/2], [-1/2*w + 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #413 matrix [[-1/2*w + 3/2, -2], [-1/2*w - 1/2, 1/2*w - 1/2]] update [[-1/2*w - 1/2, 1/2*w - 3/2], [-1, 1/2*w + 1/2]] | norms=(5, 5)
# #414 matrix [[-1/2*w + 3/2, -2], [-2, 1/2*w + 3/2]] update [[1/2*w + 3/2, 1/2*w - 3/2], [-1/2*w + 1/2, 2]] | norms=(5, 5)
# #415 matrix [[-1/2*w + 3/2, -2], [1/2*w + 3/2, -1/2*w + 1/2]] update [[-2, 1/2*w - 3/2], [-1/2*w + 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #416 matrix [[-1/2*w + 3/2, 2], [1/2*w + 1/2, 1/2*w - 1/2]] update [[1/2*w + 1/2, 1/2*w - 3/2], [-1, -1/2*w - 1/2]] | norms=(5, 5)
# #417 matrix [[-1/2*w + 3/2, 2], [2, 1/2*w + 3/2]] update [[1/2*w + 1/2, 1/2*w - 3/2], [1/2*w - 1/2, -2]] | norms=(5, 5)
# #418 matrix [[-1/2*w + 3/2, 2], [-1/2*w - 3/2, -1/2*w + 1/2]] update [[2, 1/2*w - 3/2], [-1/2*w + 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #419 matrix [[-1/2*w + 3/2, -1/2*w - 3/2], [1/2*w + 1/2, 2]] update [[1/2*w + 1/2, 1/2*w - 3/2], [-1, -1/2*w - 1/2]] | norms=(5, 5)
# #420 matrix [[-1/2*w + 3/2, -1/2*w - 3/2], [2, -1/2*w + 1/2]] update [[1/2*w + 1/2, 1/2*w - 3/2], [1/2*w - 1/2, -2]] | norms=(5, 5)
# #421 matrix [[-1/2*w + 3/2, -1/2*w - 3/2], [-1/2*w - 3/2, 1/2*w - 3/2]] update [[2, 1/2*w - 3/2], [-1/2*w + 1/2, 1/2*w + 3/2]] | norms=(5, 5)
# #422 matrix [[-1/2*w + 3/2, 1/2*w + 3/2], [-1/2*w - 1/2, 2]] update [[-1/2*w - 1/2, 1/2*w - 3/2], [-1, 1/2*w + 1/2]] | norms=(5, 5)
# #423 matrix [[-1/2*w + 3/2, 1/2*w + 3/2], [-2, -1/2*w + 1/2]] update [[1/2*w + 3/2, 1/2*w - 3/2], [-1/2*w + 1/2, 2]] | norms=(5, 5)
# #424 matrix [[-1/2*w + 3/2, 1/2*w + 3/2], [1/2*w + 3/2, 1/2*w - 3/2]] update [[-2, 1/2*w - 3/2], [-1/2*w + 1/2, -1/2*w - 3/2]] | norms=(5, 5)
# #425 matrix [[1/2*w + 3/2, -1], [1, 0]] update [[-1, -1/2*w - 3/2], [0, -1]] | norms=(5, 5)
# #426 matrix [[1/2*w + 3/2, -1], [-1/2*w - 1/2, 1]] update [[-1, -1/2*w - 3/2], [1, 1/2*w + 1/2]] | norms=(5, 5)
# #427 matrix [[1/2*w + 3/2, 1], [-1, 0]] update [[1, -1/2*w - 3/2], [0, 1]] | norms=(5, 5)
# #428 matrix [[1/2*w + 3/2, 1], [1/2*w + 1/2, 1]] update [[1, -1/2*w - 3/2], [1, -1/2*w - 1/2]] | norms=(5, 5)
# #429 matrix [[1/2*w + 3/2, -1/2*w - 1/2], [-1, 1]] update [[1, -1/2*w - 3/2], [0, 1]] | norms=(5, 5)
# #430 matrix [[1/2*w + 3/2, -1/2*w - 1/2], [1/2*w + 1/2, -1/2*w + 1/2]] update [[1, -1/2*w - 3/2], [1, -1/2*w - 1/2]] | norms=(5, 5)
# #431 matrix [[1/2*w + 3/2, 1/2*w - 1/2], [1/2*w - 1/2, -1]] update [[1/2*w - 1/2, -1/2*w - 3/2], [-1, -1/2*w + 1/2]] | norms=(5, 5)
# #432 matrix [[1/2*w + 3/2, 1/2*w - 1/2], [-2, -1/2*w - 1/2]] update [[-1/2*w + 3/2, -1/2*w - 3/2], [1/2*w + 1/2, 2]] | norms=(5, 5)
# #433 matrix [[1/2*w + 3/2, 1/2*w - 1/2], [-1/2*w + 3/2, 2]] update [[-2, -1/2*w - 3/2], [1/2*w + 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #434 matrix [[1/2*w + 3/2, -1/2*w + 1/2], [-1/2*w + 1/2, -1]] update [[-1/2*w + 1/2, -1/2*w - 3/2], [-1, 1/2*w - 1/2]] | norms=(5, 5)
# #435 matrix [[1/2*w + 3/2, -1/2*w + 1/2], [2, -1/2*w - 1/2]] update [[-1/2*w + 1/2, -1/2*w - 3/2], [-1/2*w - 1/2, -2]] | norms=(5, 5)
# #436 matrix [[1/2*w + 3/2, -1/2*w + 1/2], [1/2*w - 3/2, 2]] update [[2, -1/2*w - 3/2], [1/2*w + 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #437 matrix [[1/2*w + 3/2, 1/2*w + 1/2], [1, 1]] update [[-1, -1/2*w - 3/2], [0, -1]] | norms=(5, 5)
# #438 matrix [[1/2*w + 3/2, 1/2*w + 1/2], [-1/2*w - 1/2, -1/2*w + 1/2]] update [[-1, -1/2*w - 3/2], [1, 1/2*w + 1/2]] | norms=(5, 5)
# #439 matrix [[1/2*w + 3/2, -2], [1/2*w - 1/2, -1/2*w - 1/2]] update [[1/2*w - 1/2, -1/2*w - 3/2], [-1, -1/2*w + 1/2]] | norms=(5, 5)
# #440 matrix [[1/2*w + 3/2, -2], [-2, -1/2*w + 3/2]] update [[-1/2*w + 3/2, -1/2*w - 3/2], [1/2*w + 1/2, 2]] | norms=(5, 5)
# #441 matrix [[1/2*w + 3/2, -2], [-1/2*w + 3/2, 1/2*w + 1/2]] update [[-2, -1/2*w - 3/2], [1/2*w + 1/2, 1/2*w - 3/2]] | norms=(5, 5)
# #442 matrix [[1/2*w + 3/2, 2], [-1/2*w + 1/2, -1/2*w - 1/2]] update [[-1/2*w + 1/2, -1/2*w - 3/2], [-1, 1/2*w - 1/2]] | norms=(5, 5)
# #443 matrix [[1/2*w + 3/2, 2], [2, -1/2*w + 3/2]] update [[-1/2*w + 1/2, -1/2*w - 3/2], [-1/2*w - 1/2, -2]] | norms=(5, 5)
# #444 matrix [[1/2*w + 3/2, 2], [1/2*w - 3/2, 1/2*w + 1/2]] update [[2, -1/2*w - 3/2], [1/2*w + 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #445 matrix [[1/2*w + 3/2, 1/2*w - 3/2], [-1/2*w + 1/2, 2]] update [[-1/2*w + 1/2, -1/2*w - 3/2], [-1, 1/2*w - 1/2]] | norms=(5, 5)
# #446 matrix [[1/2*w + 3/2, 1/2*w - 3/2], [2, 1/2*w + 1/2]] update [[-1/2*w + 1/2, -1/2*w - 3/2], [-1/2*w - 1/2, -2]] | norms=(5, 5)
# #447 matrix [[1/2*w + 3/2, 1/2*w - 3/2], [1/2*w - 3/2, -1/2*w - 3/2]] update [[2, -1/2*w - 3/2], [1/2*w + 1/2, -1/2*w + 3/2]] | norms=(5, 5)
# #448 matrix [[1/2*w + 3/2, -1/2*w + 3/2], [1/2*w - 1/2, 2]] update [[1/2*w - 1/2, -1/2*w - 3/2], [-1, -1/2*w + 1/2]] | norms=(5, 5)
# #449 matrix [[1/2*w + 3/2, -1/2*w + 3/2], [-2, 1/2*w + 1/2]] update [[-1/2*w + 3/2, -1/2*w - 3/2], [1/2*w + 1/2, 2]] | norms=(5, 5)
# #450 matrix [[1/2*w + 3/2, -1/2*w + 3/2], [-1/2*w + 3/2, -1/2*w - 3/2]] update [[-2, -1/2*w - 3/2], [1/2*w + 1/2, 1/2*w - 3/2]] | norms=(5, 5)

# %%
for i, (M, N, x, y) in enumerate(result, 1):
    if x < y:
        print(f"#{i:3d} matrix {list(map(list, M.rows()))} update {list(map(list, N.rows()))} | norms=({x}, {y})")
